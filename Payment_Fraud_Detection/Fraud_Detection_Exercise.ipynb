# %% [markdown]
# # Detecting Payment Card Fraud
#
# In this section, we'll look at a credit card fraud detection dataset, and build a binary classification model that can identify transactions as either fraudulent or valid, based on provided, *historical* data. In a [2016 study](https://nilsonreport.com/upload/content_promo/The_Nilson_Report_10-17-2016.pdf), it was estimated that credit card fraud was responsible for over 20 billion dollars in loss, worldwide. Accurately detecting cases of fraud is an ongoing area of research.
#
# <img src=notebook_ims/fraud_detection.png width=50% />
#
# ### Labeled Data
#
# The payment fraud data set (Dal Pozzolo et al. 2015) was downloaded from [Kaggle](https://www.kaggle.com/mlg-ulb/creditcardfraud/data). This has features and labels for thousands of credit card transactions, each of which is labeled as fraudulent or valid. In this notebook, we'd like to train a model based on the features of these transactions so that we can predict risky or fraudulent transactions in the future.
#
# ### Binary Classification
#
# Since we have true labels to aim for, we'll take a **supervised learning** approach and train a binary classifier to sort data into one of our two transaction classes: fraudulent or valid.  We'll train a model on training data and see how well it generalizes on some test data.
#
# The notebook will be broken down into a few steps:
# * Loading and exploring the data
# * Splitting the data into train/test sets
# * Defining and training a LinearLearner, binary classifier
# * Making improvements on the model
# * Evaluating and comparing model test performance
#
# ### Making Improvements
#
# A lot of this notebook will focus on making improvements, as discussed in [this SageMaker blog post](https://aws.amazon.com/blogs/machine-learning/train-faster-more-flexible-models-with-amazon-sagemaker-linear-learner/). Specifically, we'll address techniques for:
#
# 1. **Tuning a model's hyperparameters** and aiming for a specific metric, such as high recall or precision.
# 2. **Managing class imbalance**, which is when we have many more training examples in one class than another (in this case, many more valid transactions than fraudulent).
#
# ---

# %% [markdown]
# First, import the usual resources.

# %%
import io
import os
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd 

import boto3
import sagemaker
from sagemaker import get_execution_role

# %matplotlib inline

# %% [markdown]
# I'm storing my **SageMaker variables** in the next cell:
# * sagemaker_session: The SageMaker session we'll use for training models.
# * bucket: The name of the default S3 bucket that we'll use for data storage.
# * role: The IAM role that defines our data and model permissions.

# %%
# sagemaker session, role
sagemaker_session = sagemaker.Session()
role = sagemaker.get_execution_role()

# S3 bucket name
bucket = sagemaker_session.default_bucket()

# %% [markdown]
# ## Loading and Exploring the Data
#
# Next, I am loading the data and unzipping the data in the file `creditcardfraud.zip`. This directory will hold one csv file of all the transaction data, `creditcard.csv`.
#
# As in previous notebooks, it's important to look at the distribution of data since this will inform how we develop a fraud detection model. We'll want to know: How many data points we have to work with, the number and type of features, and finally, the distribution of data over the classes (valid or fraudulent).

# %%
# only have to run once
# !wget https://s3.amazonaws.com/video.udacity-data.com/topher/2019/January/5c534768_creditcardfraud/creditcardfraud.zip
# !unzip creditcardfraud
# Out:
# --2019-11-30 13:58:59--  https://s3.amazonaws.com/video.udacity-data.com/topher/2019/January/5c534768_creditcardfraud/creditcardfraud.zip
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.217.36.150
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.217.36.150|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 69155632 (66M) [application/zip]
# Saving to: ‘creditcardfraud.zip’
#
# creditcardfraud.zip 100%[===================>]  65.95M  6.88MB/s    in 11s
#
# 2019-11-30 13:59:12 (5.84 MB/s) - ‘creditcardfraud.zip’ saved [69155632/69155632]
#
# Archive:  creditcardfraud.zip
#   inflating: creditcard.csv

# %%
# read in the csv file
local_data = 'creditcard.csv'

# print out some data
transaction_df = pd.read_csv(local_data)
print('Data shape (rows, cols): ', transaction_df.shape)
print()
transaction_df.head()
# Out:
# Data shape (rows, cols):  (284807, 31)
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %% [markdown]
# ### EXERCISE: Calculate the percentage of fraudulent data
#
# Take a look at the distribution of this transaction data over the classes, valid and fraudulent.
#
# Complete the function `fraudulent_percentage`, below. Count up the number of data points in each class and calculate the *percentage* of the data points that are fraudulent.

# %%
# Calculate the fraction of data points that are fraudulent
def fraudulent_percentage(transaction_df):
    '''Calculate the fraction of all data points that have a 'Class' label of 1; fraudulent.
       :param transaction_df: Dataframe of all transaction data points; has a column 'Class'
       :return: A fractional percentage of fraudulent data points/all points
    '''
    
    # your code here
    
    return len(transaction_df[transaction_df.Class==1])/len(transaction_df)

# %% [markdown]
# Test out your code by calling your function and printing the result.

# %%
# call the function to calculate the fraud percentage
fraud_percentage = fraudulent_percentage(transaction_df)

print('Fraudulent percentage = ', fraud_percentage)
print('Total # of fraudulent pts: ', fraud_percentage*transaction_df.shape[0])
print('Out of (total) pts: ', transaction_df.shape[0])
# Out:
# Fraudulent percentage =  0.001727485630620034
# Total # of fraudulent pts:  492.0
# Out of (total) pts:  284807

# %% [markdown]
# ### EXERCISE: Split into train/test datasets
#
# In this example, we'll want to evaluate the performance of a fraud classifier; training it on some training data and testing it on *test data* that it did not see during the training process. So, we'll need to split the data into separate training and test sets.
#
# Complete the `train_test_split` function, below. This function should:
# * Shuffle the transaction data, randomly
# * Split it into two sets according to the parameter `train_frac`
# * Get train/test features and labels
# * Return the tuples: (train_features, train_labels), (test_features, test_labels)

# %%
# split into train/test
def train_test_split(transaction_df, train_frac= 0.7, seed=1):
    '''Shuffle the data and randomly split into train and test sets;
       separate the class labels (the column in transaction_df) from the features.
       :param df: Dataframe of all credit card transaction data
       :param train_frac: The decimal fraction of data that should be training data
       :param seed: Random seed for shuffling and reproducibility, default = 1
       :return: Two tuples (in order): (train_features, train_labels), (test_features, test_labels)
       '''
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test  = train_test_split(transaction_df.drop('Class', axis=1), 
                                                         transaction_df['Class'], 
                                                         train_size=train_frac)
    # shuffle and split the data
    train_features = X_train
    train_labels = y_train
    test_features = X_test
    test_labels = y_test
    
    return (train_features, train_labels), (test_features, test_labels)

# %% [markdown]
# ### Test Cell
#
# In the cells below, I'm creating the train/test data and checking to see that result makes sense. The tests below test that the above function splits the data into the expected number of points and that the labels are indeed, class labels (0, 1).

# %%
# get train/test data
(train_features, train_labels), (test_features, test_labels) = train_test_split(transaction_df, train_frac=0.7)
# Out:
# /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2069: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
(train_features, train_labels), (test_features, test_labels) = (train_features.values, train_labels.values), (test_features.values, test_labels.values)

# %%
# manual test

# for a split of 0.7:0.3 there should be ~2.33x as many training as test pts
print('Training data pts: ', len(train_features))
print('Test data pts: ', len(test_features))
print()

# take a look at first item and see that it aligns with first row of data
print('First item: \n', train_features[0])
print('Label: ', train_labels[0])
print()

# test split
assert len(train_features) > 2.333*len(test_features), \
        'Unexpected number of train/test points for a train_frac=0.7'
# test labels
assert np.all(train_labels)== 0 or np.all(train_labels)== 1, \
        'Train labels should be 0s or 1s.'
assert np.all(test_labels)== 0 or np.all(test_labels)== 1, \
        'Test labels should be 0s or 1s.'
print('Tests passed!')
# Out:
# Training data pts:  199364
# Test data pts:  85443
#
# First item:
#  [ 7.93290000e+04  1.24595251e+00 -4.33723269e-01  8.86356376e-01
#  -7.13542076e-01 -1.31529374e+00 -8.53377852e-01 -6.52333485e-01
#   3.35178366e-02  1.99941044e+00 -1.04529947e+00 -6.38499513e-01
#   1.15933818e-01 -1.21702566e+00  8.52787323e-02  1.40113733e+00
#  -3.87484013e-01 -7.74945236e-02  3.31826084e-01  5.63764530e-01
#  -2.01104625e-01 -2.58330261e-02  1.18080203e-01 -2.15004170e-02
#   3.77328208e-01  4.60347447e-01 -6.82662383e-01  8.59617107e-02
#   3.27741399e-02  1.00000000e+00]
# Label:  0
#
# Tests passed!

# %% [markdown]
# ---
# # Modeling
#
# Now that you've uploaded your training data, it's time to define and train a model!
#
# In this notebook, you'll define and train the SageMaker, built-in algorithm, [LinearLearner](https://sagemaker.readthedocs.io/en/stable/linear_learner.html).
#
# A LinearLearner has two main applications:
# 1. For regression tasks in which a linear line is fit to some data points, and you want to produce a predicted output value given some data point (example: predicting house prices given square area).
# 2. For binary classification, in which a line is separating two classes of data and effectively outputs labels; either 1 for data that falls above the line or 0 for points that fall on or below the line.
#
# <img src='notebook_ims/linear_separator.png' width=50% />
#
# In this case, we'll be using it for case 2, and we'll train it to separate data into our two classes: valid or fraudulent.

# %% [markdown]
# ### EXERCISE: Create a LinearLearner Estimator
#
# You've had some practice instantiating built-in models in SageMaker. All estimators require some constructor arguments to be passed in. See if you can complete this task, instantiating a LinearLearner estimator, using only the [LinearLearner documentation](https://sagemaker.readthedocs.io/en/stable/linear_learner.html) as a resource. This takes in a lot of arguments, but not all are required. My suggestion is to start with a simple model, utilizing default values where applicable. Later, we will discuss some specific hyperparameters and their use cases.
#
# #### Instance Types
#
# It is suggested that you use instances that are available in the free tier of usage: `'ml.c4.xlarge'` for training and `'ml.t2.medium'` for deployment.

# %%
# import LinearLearner
from sagemaker import LinearLearner

prefix = 'creditcard'
output_path = f's3://{bucket}/{prefix}'

# instantiate LinearLearner
lm = LinearLearner(
    role=role,
    train_instance_count=1,
    train_instance_type='ml.c4.xlarge',
    predictor_type='binary_classifier',
    binary_classifier_model_selection_criteria='f1',
    positive_example_weight_mult=2.0,
    epochs=15,
    output_path=output_path
)

# %% [markdown]
# ### EXERCISE: Convert data into a RecordSet format
#
# Next, prepare the data for a built-in model by converting the train features and labels into numpy array's of float values. Then you can use the [record_set function](https://sagemaker.readthedocs.io/en/stable/linear_learner.html#sagemaker.LinearLearner.record_set) to format the data as a RecordSet and prepare it for training!

# %%
# create RecordSet of training data
formatted_train_data = lm.record_set(train_features.astype('float32'), train_labels.astype('float32'))

# %% [markdown]
# ### EXERCISE: Train the Estimator
#
# After instantiating your estimator, train it with a call to `.fit()`, passing in the formatted training data.

# %%
# %%time 
# train the estimator on formatted training data
lm.fit(formatted_train_data)
# Out:
# 2019-11-30 14:29:58 Starting - Starting the training job...
# 2019-11-30 14:30:00 Starting - Launching requested ML instances......
# 2019-11-30 14:31:06 Starting - Preparing the instances for training......
# 2019-11-30 14:32:10 Downloading - Downloading input data...
# 2019-11-30 14:32:53 Training - Training image download completed. Training in progress..Docker entrypoint called with argument(s): train
# [11/30/2019 14:32:55 INFO 140339651753792] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [11/30/2019 14:32:55 INFO 140339651753792] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'predictor_type': u'binary_classifier', u'feature_dim': u'30', u'binary_classifier_model_selection_criteria': u'f1', u'epochs': u'15', u'positive_example_weight_mult': u'2.0', u'mini_batch_size': u'1000'}
# [11/30/2019 14:32:55 INFO 140339651753792] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'30', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'f1', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'binary_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'2.0', u'l1': u'auto', u'margin': u'1.0'}
# [11/30/2019 14:32:55 WARNING 140339651753792] Loggers have already been setup.
# Process 1 is a worker.
# [11/30/2019 14:32:55 INFO 140339651753792] Using default worker.
# [2019-11-30 14:32:55.902] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 27, "num_examples": 1, "num_bytes": 168000}
# [11/30/2019 14:32:55 INFO 140339651753792] Create Store: local
# [2019-11-30 14:32:55.949] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 46, "num_examples": 11, "num_bytes": 1848000}
# [11/30/2019 14:32:55 INFO 140339651753792] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7fa30de59190>
# [11/30/2019 14:32:55 INFO 140339651753792] Scaling model computed with parameters:
#  {'stdev_weight':
# [4.7562535e+04 1.9419131e+00 1.6394308e+00 1.4789869e+00 1.4170419e+00
#  1.3764122e+00 1.3037390e+00 1.2100444e+00 1.1044248e+00 1.0992875e+00
#  1.0769122e+00 1.0212113e+00 1.0144311e+00 9.9730700e-01 9.6627188e-01
#  9.0953732e-01 8.7584490e-01 8.5975999e-01 8.4108406e-01 8.0306906e-01
#  7.6150602e-01 7.0069093e-01 7.2143131e-01 6.8534207e-01 5.9842288e-01
#  5.2408093e-01 4.8172125e-01 3.9511588e-01 3.1953603e-01 2.4329514e+02]
# <NDArray 30 @cpu(0)>, 'stdev_label': None, 'mean_label': None, 'mean_weight':
# [ 9.4516172e+04  1.3381084e-02 -1.8507825e-02  3.0525655e-03
#   1.2956868e-02  3.7997791e-03 -2.6551291e-02  1.1056175e-02
#   1.0034550e-03 -3.9743842e-03  1.7335627e-02  2.0118803e-02
#  -5.0890758e-03 -1.4744978e-02  1.0867137e-02  1.8783055e-02
#  -4.3995297e-03 -1.2560965e-02  1.2526816e-03 -4.9423994e-03
#  -7.0784549e-04  1.9289013e-03 -5.4737069e-03 -3.7858561e-03
#   6.4815176e-03  1.0366203e-03 -3.8535960e-03  3.3881629e-04
#  -3.2593647e-03  8.9556389e+01]
# <NDArray 30 @cpu(0)>}
# [11/30/2019 14:32:55 INFO 140339651753792] nvidia-smi took: 0.0251679420471 secs to identify 0 gpus
# [11/30/2019 14:32:55 INFO 140339651753792] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 11, "sum": 11.0, "min": 11}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 12, "sum": 12.0, "min": 12}, "Total Records Seen": {"count": 1, "max": 12000, "sum": 12000.0, "min": 12000}, "Max Records Seen Between Resets": {"count": 1, "max": 11000, "sum": 11000.0, "min": 11000}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1575124376.112471, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1575124376.112434}
#
# [2019-11-30 14:33:02.517] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 3, "duration": 6404, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.12174358549070119, "sum": 0.12174358549070119, "min": 0.12174358549070119}}, "EndTime": 1575124382.517251, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575124382.517147}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.11902005684435667, "sum": 0.11902005684435667, "min": 0.11902005684435667}}, "EndTime": 1575124382.517345, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575124382.51733}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.12147517374891732, "sum": 0.12147517374891732, "min": 0.12147517374891732}}, "EndTime": 1575124382.517393, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575124382.517381}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.11923794046718271, "sum": 0.11923794046718271, "min": 0.11923794046718271}}, "EndTime": 1575124382.517436, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575124382.517425}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.015551511758498511, "sum": 0.015551511758498511, "min": 0.015551511758498511}}, "EndTime": 1575124382.517477, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575124382.517466}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.015128680933435359, "sum": 0.015128680933435359, "min": 0.015128680933435359}}, "EndTime": 1575124382.517533, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575124382.51752}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.015424135468713003, "sum": 0.015424135468713003, "min": 0.015424135468713003}}, "EndTime": 1575124382.517576, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575124382.517565}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.01526581434141751, "sum": 0.01526581434141751, "min": 0.01526581434141751}}, "EndTime": 1575124382.517624, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575124382.517612}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.12157748048868611, "sum": 0.12157748048868611, "min": 0.12157748048868611}}, "EndTime": 1575124382.517672, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575124382.517661}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.11930237652189168, "sum": 0.11930237652189168, "min": 0.11930237652189168}}, "EndTime": 1575124382.517713, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575124382.517703}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.12191141243556038, "sum": 0.12191141243556038, "min": 0.12191141243556038}}, "EndTime": 1575124382.517755, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575124382.517745}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.11926035804365148, "sum": 0.11926035804365148, "min": 0.11926035804365148}}, "EndTime": 1575124382.517797, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575124382.517787}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.015353473393124852, "sum": 0.015353473393124852, "min": 0.015353473393124852}}, "EndTime": 1575124382.517837, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575124382.517827}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.015616100299036383, "sum": 0.015616100299036383, "min": 0.015616100299036383}}, "EndTime": 1575124382.517883, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575124382.517872}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.01567890694557722, "sum": 0.01567890694557722, "min": 0.01567890694557722}}, "EndTime": 1575124382.51794, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575124382.517919}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.01564082768248703, "sum": 0.01564082768248703, "min": 0.01564082768248703}}, "EndTime": 1575124382.517982, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575124382.517971}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.12623157043073643, "sum": 0.12623157043073643, "min": 0.12623157043073643}}, "EndTime": 1575124382.518021, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575124382.51801}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.12356770169435434, "sum": 0.12356770169435434, "min": 0.12356770169435434}}, "EndTime": 1575124382.51806, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575124382.51805}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.12615610794565785, "sum": 0.12615610794565785, "min": 0.12615610794565785}}, "EndTime": 1575124382.518105, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575124382.518094}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.12367759701714444, "sum": 0.12367759701714444, "min": 0.12367759701714444}}, "EndTime": 1575124382.518151, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575124382.51814}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.02765075871629182, "sum": 0.02765075871629182, "min": 0.02765075871629182}}, "EndTime": 1575124382.518196, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575124382.518185}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.02757060133658312, "sum": 0.02757060133658312, "min": 0.02757060133658312}}, "EndTime": 1575124382.518235, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575124382.518225}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.027743367800460987, "sum": 0.027743367800460987, "min": 0.027743367800460987}}, "EndTime": 1575124382.518272, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575124382.518262}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.02756217322101695, "sum": 0.02756217322101695, "min": 0.02756217322101695}}, "EndTime": 1575124382.518313, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575124382.518303}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.12872142286636123, "sum": 0.12872142286636123, "min": 0.12872142286636123}}, "EndTime": 1575124382.518358, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575124382.518347}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.12617109421389786, "sum": 0.12617109421389786, "min": 0.12617109421389786}}, "EndTime": 1575124382.518403, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575124382.518393}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.12874621722925847, "sum": 0.12874621722925847, "min": 0.12874621722925847}}, "EndTime": 1575124382.518448, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575124382.518435}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.12625859850016072, "sum": 0.12625859850016072, "min": 0.12625859850016072}}, "EndTime": 1575124382.518495, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575124382.518485}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.03130526627405505, "sum": 0.03130526627405505, "min": 0.03130526627405505}}, "EndTime": 1575124382.518523, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575124382.518516}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.03118811667118989, "sum": 0.03118811667118989, "min": 0.03118811667118989}}, "EndTime": 1575124382.518549, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575124382.518542}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.03120676196467637, "sum": 0.03120676196467637, "min": 0.03120676196467637}}, "EndTime": 1575124382.518595, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575124382.518582}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.031168312040555417, "sum": 0.031168312040555417, "min": 0.031168312040555417}}, "EndTime": 1575124382.518645, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575124382.518631}
#
# [11/30/2019 14:33:02 INFO 140339651753792] #quality_metric: host=algo-1, epoch=0, train binary_classification_weighted_cross_entropy_objective <loss>=0.121743585491
# [11/30/2019 14:33:02 INFO 140339651753792] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=binary_classification_weighted_cross_entropy_objective, value=0.0151286809334
# [11/30/2019 14:33:02 INFO 140339651753792] Epoch 0: Loss improved. Updating best model
# [11/30/2019 14:33:02 INFO 140339651753792] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 212, "sum": 212.0, "min": 212}, "Total Records Seen": {"count": 1, "max": 211364, "sum": 211364.0, "min": 211364}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1575124382.521963, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575124376.112679}
#
# [11/30/2019 14:33:02 INFO 140339651753792] #throughput_metric: host=algo-1, train throughput=31104.9200167 records/second
# [2019-11-30 14:33:09.310] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 5, "duration": 6786, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.0189186034178614, "sum": 0.0189186034178614, "min": 0.0189186034178614}}, "EndTime": 1575124389.310849, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575124389.310746}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.01696451397996452, "sum": 0.01696451397996452, "min": 0.01696451397996452}}, "EndTime": 1575124389.310962, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575124389.310939}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.018897051887895595, "sum": 0.018897051887895595, "min": 0.018897051887895595}}, "EndTime": 1575124389.311037, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575124389.311016}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.016978650730458934, "sum": 0.016978650730458934, "min": 0.016978650730458934}}, "EndTime": 1575124389.311105, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575124389.311086}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.008496067602730277, "sum": 0.008496067602730277, "min": 0.008496067602730277}}, "EndTime": 1575124389.311172, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575124389.311153}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.010023753024225857, "sum": 0.010023753024225857, "min": 0.010023753024225857}}, "EndTime": 1575124389.311238, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575124389.311219}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.009966150971213776, "sum": 0.009966150971213776, "min": 0.009966150971213776}}, "EndTime": 1575124389.311299, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575124389.311281}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.010435123533010482, "sum": 0.010435123533010482, "min": 0.010435123533010482}}, "EndTime": 1575124389.311359, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575124389.311342}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.019128502970364825, "sum": 0.019128502970364825, "min": 0.019128502970364825}}, "EndTime": 1575124389.311417, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575124389.3114}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.017224068871694594, "sum": 0.017224068871694594, "min": 0.017224068871694594}}, "EndTime": 1575124389.311478, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575124389.311462}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.01914713515468578, "sum": 0.01914713515468578, "min": 0.01914713515468578}}, "EndTime": 1575124389.31155, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575124389.311523}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.017220783511597906, "sum": 0.017220783511597906, "min": 0.017220783511597906}}, "EndTime": 1575124389.311608, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575124389.311592}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.008860473796650392, "sum": 0.008860473796650392, "min": 0.008860473796650392}}, "EndTime": 1575124389.311667, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575124389.311652}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.008753946470555348, "sum": 0.008753946470555348, "min": 0.008753946470555348}}, "EndTime": 1575124389.311725, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575124389.311709}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.008820708512361325, "sum": 0.008820708512361325, "min": 0.008820708512361325}}, "EndTime": 1575124389.311785, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575124389.311769}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.008738433683038357, "sum": 0.008738433683038357, "min": 0.008738433683038357}}, "EndTime": 1575124389.311841, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575124389.311826}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.026671825490405213, "sum": 0.026671825490405213, "min": 0.026671825490405213}}, "EndTime": 1575124389.31189, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575124389.311876}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.025129181698938113, "sum": 0.025129181698938113, "min": 0.025129181698938113}}, "EndTime": 1575124389.311932, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575124389.311922}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.026662177982042783, "sum": 0.026662177982042783, "min": 0.026662177982042783}}, "EndTime": 1575124389.31196, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575124389.311953}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.025123457606713376, "sum": 0.025123457606713376, "min": 0.025123457606713376}}, "EndTime": 1575124389.311991, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575124389.311983}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.01953634007851682, "sum": 0.01953634007851682, "min": 0.01953634007851682}}, "EndTime": 1575124389.312044, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575124389.312026}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.019411325332507418, "sum": 0.019411325332507418, "min": 0.019411325332507418}}, "EndTime": 1575124389.312101, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575124389.312085}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.019519882206940772, "sum": 0.019519882206940772, "min": 0.019519882206940772}}, "EndTime": 1575124389.31217, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575124389.312152}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.019456583607735944, "sum": 0.019456583607735944, "min": 0.019456583607735944}}, "EndTime": 1575124389.312232, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575124389.312215}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.029887009726097834, "sum": 0.029887009726097834, "min": 0.029887009726097834}}, "EndTime": 1575124389.3123, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575124389.312282}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.028356633128832333, "sum": 0.028356633128832333, "min": 0.028356633128832333}}, "EndTime": 1575124389.312361, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575124389.312344}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.029879978893989294, "sum": 0.029879978893989294, "min": 0.029879978893989294}}, "EndTime": 1575124389.312419, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575124389.312403}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.028356188841201554, "sum": 0.028356188841201554, "min": 0.028356188841201554}}, "EndTime": 1575124389.312481, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575124389.312465}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.022915025745803987, "sum": 0.022915025745803987, "min": 0.022915025745803987}}, "EndTime": 1575124389.312547, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575124389.31253}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.022930907847294256, "sum": 0.022930907847294256, "min": 0.022930907847294256}}, "EndTime": 1575124389.312603, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575124389.31259}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.022912115590656222, "sum": 0.022912115590656222, "min": 0.022912115590656222}}, "EndTime": 1575124389.312644, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575124389.31263}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.022934197126321457, "sum": 0.022934197126321457, "min": 0.022934197126321457}}, "EndTime": 1575124389.3127, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575124389.312688}
#
# [11/30/2019 14:33:09 INFO 140339651753792] #quality_metric: host=algo-1, epoch=1, train binary_classification_weighted_cross_entropy_objective <loss>=0.0189186034179
# [11/30/2019 14:33:09 INFO 140339651753792] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=binary_classification_weighted_cross_entropy_objective, value=0.00849606760273
# [11/30/2019 14:33:09 INFO 140339651753792] Epoch 1: Loss improved. Updating best model
# [11/30/2019 14:33:09 INFO 140339651753792] #progress_metric: host=algo-1, completed 13 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 412, "sum": 412.0, "min": 412}, "Total Records Seen": {"count": 1, "max": 410728, "sum": 410728.0, "min": 410728}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 1575124389.315299, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575124382.523539}
#
# [11/30/2019 14:33:09 INFO 140339651753792] #throughput_metric: host=algo-1, train throughput=29353.24376 records/second
# [2019-11-30 14:33:15.233] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 7, "duration": 5916, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.012423835946087862, "sum": 0.012423835946087862, "min": 0.012423835946087862}}, "EndTime": 1575124395.233974, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575124395.233868}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.010906056797085097, "sum": 0.010906056797085097, "min": 0.010906056797085097}}, "EndTime": 1575124395.234044, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575124395.234032}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.012409458848100212, "sum": 0.012409458848100212, "min": 0.012409458848100212}}, "EndTime": 1575124395.234104, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575124395.234088}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.010924749867999973, "sum": 0.010924749867999973, "min": 0.010924749867999973}}, "EndTime": 1575124395.234149, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575124395.234133}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.00884779145123072, "sum": 0.00884779145123072, "min": 0.00884779145123072}}, "EndTime": 1575124395.234216, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575124395.234198}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.009810203761461392, "sum": 0.009810203761461392, "min": 0.009810203761461392}}, "EndTime": 1575124395.23428, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575124395.234262}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.009352647199702623, "sum": 0.009352647199702623, "min": 0.009352647199702623}}, "EndTime": 1575124395.234344, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575124395.234326}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.009301949940284892, "sum": 0.009301949940284892, "min": 0.009301949940284892}}, "EndTime": 1575124395.234403, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575124395.234386}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.012792001582869333, "sum": 0.012792001582869333, "min": 0.012792001582869333}}, "EndTime": 1575124395.234485, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575124395.234456}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.011342871848063252, "sum": 0.011342871848063252, "min": 0.011342871848063252}}, "EndTime": 1575124395.23455, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575124395.234533}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.012801889726264991, "sum": 0.012801889726264991, "min": 0.012801889726264991}}, "EndTime": 1575124395.234619, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575124395.2346}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.011342948911178052, "sum": 0.011342948911178052, "min": 0.011342948911178052}}, "EndTime": 1575124395.234688, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575124395.23467}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.008647980380297906, "sum": 0.008647980380297906, "min": 0.008647980380297906}}, "EndTime": 1575124395.234756, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575124395.234737}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.008750278160799688, "sum": 0.008750278160799688, "min": 0.008750278160799688}}, "EndTime": 1575124395.234825, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575124395.234808}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.008539497445576154, "sum": 0.008539497445576154, "min": 0.008539497445576154}}, "EndTime": 1575124395.23488, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575124395.234866}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.008813484522565525, "sum": 0.008813484522565525, "min": 0.008813484522565525}}, "EndTime": 1575124395.234937, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575124395.23492}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.021680024173391526, "sum": 0.021680024173391526, "min": 0.021680024173391526}}, "EndTime": 1575124395.235006, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575124395.234986}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.020766311123143488, "sum": 0.020766311123143488, "min": 0.020766311123143488}}, "EndTime": 1575124395.235073, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575124395.235055}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.021675933574312297, "sum": 0.021675933574312297, "min": 0.021675933574312297}}, "EndTime": 1575124395.235135, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575124395.235118}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.02076284247546939, "sum": 0.02076284247546939, "min": 0.02076284247546939}}, "EndTime": 1575124395.235204, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575124395.235186}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.019656346376217788, "sum": 0.019656346376217788, "min": 0.019656346376217788}}, "EndTime": 1575124395.235271, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575124395.235253}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.019450312512004794, "sum": 0.019450312512004794, "min": 0.019450312512004794}}, "EndTime": 1575124395.235338, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575124395.235321}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.01964867278199699, "sum": 0.01964867278199699, "min": 0.01964867278199699}}, "EndTime": 1575124395.235408, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575124395.235388}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.019481443581269613, "sum": 0.019481443581269613, "min": 0.019481443581269613}}, "EndTime": 1575124395.23547, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575124395.235453}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.02501877919393568, "sum": 0.02501877919393568, "min": 0.02501877919393568}}, "EndTime": 1575124395.235529, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575124395.235512}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.024119077672910452, "sum": 0.024119077672910452, "min": 0.024119077672910452}}, "EndTime": 1575124395.235594, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575124395.235576}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.02501579648406062, "sum": 0.02501579648406062, "min": 0.02501579648406062}}, "EndTime": 1575124395.235653, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575124395.235636}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.024116893444828053, "sum": 0.024116893444828053, "min": 0.024116893444828053}}, "EndTime": 1575124395.23571, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575124395.235694}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.02292412610988521, "sum": 0.02292412610988521, "min": 0.02292412610988521}}, "EndTime": 1575124395.235768, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575124395.235752}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.02294269184790664, "sum": 0.02294269184790664, "min": 0.02294269184790664}}, "EndTime": 1575124395.235827, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575124395.23581}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.02292313941160039, "sum": 0.02292313941160039, "min": 0.02292313941160039}}, "EndTime": 1575124395.23589, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575124395.235873}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.022943762810985046, "sum": 0.022943762810985046, "min": 0.022943762810985046}}, "EndTime": 1575124395.235949, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575124395.235932}
#
# [11/30/2019 14:33:15 INFO 140339651753792] #quality_metric: host=algo-1, epoch=2, train binary_classification_weighted_cross_entropy_objective <loss>=0.0124238359461
# [11/30/2019 14:33:15 INFO 140339651753792] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=binary_classification_weighted_cross_entropy_objective, value=0.00853949744558
# [11/30/2019 14:33:15 INFO 140339651753792] #progress_metric: host=algo-1, completed 20 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 612, "sum": 612.0, "min": 612}, "Total Records Seen": {"count": 1, "max": 610092, "sum": 610092.0, "min": 610092}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1575124395.238078, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575124389.316926}
#
# [11/30/2019 14:33:15 INFO 140339651753792] #throughput_metric: host=algo-1, train throughput=33669.1398635 records/second
# [2019-11-30 14:33:22.317] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 9, "duration": 7077, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.010197874402281029, "sum": 0.010197874402281029, "min": 0.010197874402281029}}, "EndTime": 1575124402.317584, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1575124402.317483}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.008943854726139625, "sum": 0.008943854726139625, "min": 0.008943854726139625}}, "EndTime": 1575124402.317663, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1575124402.317645}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.010190043971766179, "sum": 0.010190043971766179, "min": 0.010190043971766179}}, "EndTime": 1575124402.317721, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1575124402.317705}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.008959193823924615, "sum": 0.008959193823924615, "min": 0.008959193823924615}}, "EndTime": 1575124402.317777, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1575124402.317761}
#
# ...
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.007207878110396802, "sum": 0.007207878110396802, "min": 0.007207878110396802}}, "EndTime": 1575124472.888534, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575124472.888517}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.006926631978109254, "sum": 0.006926631978109254, "min": 0.006926631978109254}}, "EndTime": 1575124472.888604, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575124472.888585}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.0070750887157329965, "sum": 0.0070750887157329965, "min": 0.0070750887157329965}}, "EndTime": 1575124472.888675, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575124472.888657}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.00925474175878206, "sum": 0.00925474175878206, "min": 0.00925474175878206}}, "EndTime": 1575124472.888751, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575124472.888732}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.006983265525731609, "sum": 0.006983265525731609, "min": 0.006983265525731609}}, "EndTime": 1575124472.888847, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575124472.888826}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.008794228970630084, "sum": 0.008794228970630084, "min": 0.008794228970630084}}, "EndTime": 1575124472.888909, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575124472.888892}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.008150260789909554, "sum": 0.008150260789909554, "min": 0.008150260789909554}}, "EndTime": 1575124472.888986, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575124472.88896}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.007903391593065693, "sum": 0.007903391593065693, "min": 0.007903391593065693}}, "EndTime": 1575124472.889056, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575124472.889038}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.00815098076968936, "sum": 0.00815098076968936, "min": 0.00815098076968936}}, "EndTime": 1575124472.889119, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575124472.8891}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.007903285816087196, "sum": 0.007903285816087196, "min": 0.007903285816087196}}, "EndTime": 1575124472.889181, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575124472.889164}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.007928558497572664, "sum": 0.007928558497572664, "min": 0.007928558497572664}}, "EndTime": 1575124472.889241, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575124472.889223}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.00876560089396472, "sum": 0.00876560089396472, "min": 0.00876560089396472}}, "EndTime": 1575124472.889298, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575124472.889282}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.007930097001281815, "sum": 0.007930097001281815, "min": 0.007930097001281815}}, "EndTime": 1575124472.889357, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575124472.88934}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.0087656792309416, "sum": 0.0087656792309416, "min": 0.0087656792309416}}, "EndTime": 1575124472.889418, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575124472.889401}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.019442924179623476, "sum": 0.019442924179623476, "min": 0.019442924179623476}}, "EndTime": 1575124472.889478, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575124472.88946}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.01939767782053157, "sum": 0.01939767782053157, "min": 0.01939767782053157}}, "EndTime": 1575124472.889539, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575124472.889521}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.019442894996710158, "sum": 0.019442894996710158, "min": 0.019442894996710158}}, "EndTime": 1575124472.889599, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575124472.889581}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.01939755470549042, "sum": 0.01939755470549042, "min": 0.01939755470549042}}, "EndTime": 1575124472.889659, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575124472.889642}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.01942630562830211, "sum": 0.01942630562830211, "min": 0.01942630562830211}}, "EndTime": 1575124472.889716, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575124472.889699}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.019597641309901097, "sum": 0.019597641309901097, "min": 0.019597641309901097}}, "EndTime": 1575124472.889775, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575124472.889757}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.01942622201766201, "sum": 0.01942622201766201, "min": 0.01942622201766201}}, "EndTime": 1575124472.889843, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575124472.889825}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.01959786747268696, "sum": 0.01959786747268696, "min": 0.01959786747268696}}, "EndTime": 1575124472.889898, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575124472.889881}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.022852886464727582, "sum": 0.022852886464727582, "min": 0.022852886464727582}}, "EndTime": 1575124472.889954, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575124472.889938}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.022847379956413155, "sum": 0.022847379956413155, "min": 0.022847379956413155}}, "EndTime": 1575124472.890009, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575124472.889992}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.022853054389282687, "sum": 0.022853054389282687, "min": 0.022853054389282687}}, "EndTime": 1575124472.890061, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575124472.890045}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.022847344441629534, "sum": 0.022847344441629534, "min": 0.022847344441629534}}, "EndTime": 1575124472.890114, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575124472.890098}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.02286336836982612, "sum": 0.02286336836982612, "min": 0.02286336836982612}}, "EndTime": 1575124472.890176, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575124472.890159}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.023060968844734842, "sum": 0.023060968844734842, "min": 0.023060968844734842}}, "EndTime": 1575124472.890229, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575124472.890213}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.022866051268937, "sum": 0.022866051268937, "min": 0.022866051268937}}, "EndTime": 1575124472.890285, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575124472.890268}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.02306147997582977, "sum": 0.02306147997582977, "min": 0.02306147997582977}}, "EndTime": 1575124472.890354, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575124472.890337}
#
# [11/30/2019 14:34:32 INFO 140339651753792] #quality_metric: host=algo-1, epoch=14, train binary_classification_weighted_cross_entropy_objective <loss>=0.00720907071308
# [11/30/2019 14:34:32 INFO 140339651753792] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=binary_classification_weighted_cross_entropy_objective, value=0.00686699412037
# [11/30/2019 14:34:32 INFO 140339651753792] Epoch 14: Loss improved. Updating best model
# [11/30/2019 14:34:32 INFO 140339651753792] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 3012, "sum": 3012.0, "min": 3012}, "Total Records Seen": {"count": 1, "max": 3002460, "sum": 3002460.0, "min": 3002460}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 17, "sum": 17.0, "min": 17}}, "EndTime": 1575124472.893257, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575124466.469746}
#
# [11/30/2019 14:34:32 INFO 140339651753792] #throughput_metric: host=algo-1, train throughput=31035.9811581 records/second
# [11/30/2019 14:34:32 WARNING 140339651753792] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [11/30/2019 14:34:32 WARNING 140339651753792] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2019-11-30 14:34:32.900] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 33, "duration": 5, "num_examples": 1, "num_bytes": 168000}
# [2019-11-30 14:34:33.534] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 36, "duration": 629, "num_examples": 200, "num_bytes": 33493152}
# [2019-11-30 14:34:34.271] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 38, "duration": 660, "num_examples": 200, "num_bytes": 33493152}
# [11/30/2019 14:34:34 INFO 140339651753792] #train_score (algo-1) : ('binary_classification_weighted_cross_entropy_objective', 0.006748777752975857)
# [11/30/2019 14:34:34 INFO 140339651753792] #train_score (algo-1) : ('binary_classification_accuracy', 0.9992726871451215)
# [11/30/2019 14:34:34 INFO 140339651753792] #train_score (algo-1) : ('binary_f_1.000', 0.7883211678832117)
# [11/30/2019 14:34:34 INFO 140339651753792] #train_score (algo-1) : ('precision', 0.7871720116618076)
# [11/30/2019 14:34:34 INFO 140339651753792] #train_score (algo-1) : ('recall', 0.7894736842105263)
# [11/30/2019 14:34:34 INFO 140339651753792] #quality_metric: host=algo-1, train binary_classification_weighted_cross_entropy_objective <loss>=0.00674877775298
# [11/30/2019 14:34:34 INFO 140339651753792] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.999272687145
# [11/30/2019 14:34:34 INFO 140339651753792] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.788321167883
# [11/30/2019 14:34:34 INFO 140339651753792] #quality_metric: host=algo-1, train precision <score>=0.787172011662
# [11/30/2019 14:34:34 INFO 140339651753792] #quality_metric: host=algo-1, train recall <score>=0.789473684211
# [11/30/2019 14:34:34 INFO 140339651753792] Best model found for hyperparameters: {"lr_scheduler_step": 100, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.005, "lr_scheduler_minimum_lr": 1e-05}
# [11/30/2019 14:34:34 INFO 140339651753792] Saved checkpoint to "/tmp/tmpLzZAsU/mx-mod-0000.params"
# [11/30/2019 14:34:34 INFO 140339651753792] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 98488.91615867615, "sum": 98488.91615867615, "min": 98488.91615867615}, "finalize.time": {"count": 1, "max": 1379.4989585876465, "sum": 1379.4989585876465, "min": 1379.4989585876465}, "initialize.time": {"count": 1, "max": 234.85112190246582, "sum": 234.85112190246582, "min": 234.85112190246582}, "check_early_stopping.time": {"count": 15, "max": 0.9810924530029297, "sum": 11.67607307434082, "min": 0.1990795135498047}, "setuptime": {"count": 1, "max": 24.958133697509766, "sum": 24.958133697509766, "min": 24.958133697509766}, "update.time": {"count": 15, "max": 7082.345962524414, "sum": 96759.78899002075, "min": 5920.974016189575}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1575124474.286568, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1575124375.873651}
#
#
# 2019-11-30 14:34:42 Uploading - Uploading generated training model
# 2019-11-30 14:34:42 Completed - Training job completed
# Training seconds: 152
# Billable seconds: 152
# CPU times: user 733 ms, sys: 32.9 ms, total: 766 ms
# Wall time: 5min 13s

# %% [markdown]
# ### EXERCISE: Deploy the trained model
#
# Deploy your model to create a predictor. We'll use this to make predictions on our test data and evaluate the model.

# %%
# %%time 
# deploy and create a predictor
linear_predictor = lm.deploy(
    initial_instance_count=1,
    instance_type='ml.t2.medium'
)
# Out:
# --------------------------------------------------------------------------------------!CPU times: user 458 ms, sys: 33.4 ms, total: 491 ms
# Wall time: 7min 14s

# %% [markdown]
# ---
# # Evaluating Your Model
#
# Once your model is deployed, you can see how it performs when applied to the test data.
#
# According to the deployed [predictor documentation](https://sagemaker.readthedocs.io/en/stable/linear_learner.html#sagemaker.LinearLearnerPredictor), this predictor expects an `ndarray` of input features and returns a list of Records.
# > "The prediction is stored in the "predicted_label" key of the `Record.label` field."
#
# Let's first test our model on just one test point, to see the resulting list.

# %%
# test one prediction
test_x_np = test_features.astype('float32')
result = linear_predictor.predict(test_x_np[0])

print(result)
# Out:
# [label {
#   key: "predicted_label"
#   value {
#     float32_tensor {
#       values: 0.0
#     }
#   }
# }
# label {
#   key: "score"
#   value {
#     float32_tensor {
#       values: 0.0005183682078495622
#     }
#   }
# }
# ]

# %% [markdown]
# ### Helper function for evaluation
#
#
# The provided function below, takes in a deployed predictor, some test features and labels, and returns a dictionary of metrics; calculating false negatives and positives as well as recall, precision, and accuracy.

# %%
# code to evaluate the endpoint on test data
# returns a variety of model metrics
def evaluate(predictor, test_features, test_labels, verbose=True):
    """
    Evaluate a model on a test set given the prediction endpoint.  
    Return binary classification metrics.
    :param predictor: A prediction endpoint
    :param test_features: Test features
    :param test_labels: Class labels for test data
    :param verbose: If True, prints a table of all performance metrics
    :return: A dictionary of performance metrics.
    """
    
    # We have a lot of test data, so we'll split it into batches of 100
    # split the test data set into batches and evaluate using prediction endpoint    
    prediction_batches = [predictor.predict(batch) for batch in np.array_split(test_features, 100)]
    
    # LinearLearner produces a `predicted_label` for each data point in a batch
    # get the 'predicted_label' for every point in a batch
    test_preds = np.concatenate([np.array([x.label['predicted_label'].float32_tensor.values[0] for x in batch]) 
                                 for batch in prediction_batches])
    
    # calculate true positives, false positives, true negatives, false negatives
    tp = np.logical_and(test_labels, test_preds).sum()
    fp = np.logical_and(1-test_labels, test_preds).sum()
    tn = np.logical_and(1-test_labels, 1-test_preds).sum()
    fn = np.logical_and(test_labels, 1-test_preds).sum()
    
    # calculate binary classification metrics
    recall = tp / (tp + fn)
    precision = tp / (tp + fp)
    accuracy = (tp + tn) / (tp + fp + tn + fn)
    
    # printing a table of metrics
    if verbose:
        print(pd.crosstab(test_labels, test_preds, rownames=['actual (row)'], colnames=['prediction (col)']))
        print("\n{:<11} {:.3f}".format('Recall:', recall))
        print("{:<11} {:.3f}".format('Precision:', precision))
        print("{:<11} {:.3f}".format('Accuracy:', accuracy))
        print()
        
    return {'TP': tp, 'FP': fp, 'FN': fn, 'TN': tn, 
            'Precision': precision, 'Recall': recall, 'Accuracy': accuracy}

# %% [markdown]
# ### Test Results
#
# The cell below runs the `evaluate` function.
#
# The code assumes that you have a defined `predictor` and `test_features` and `test_labels` from previously-run cells.

# %%
print('Metrics for simple, LinearLearner.\n')

# get metrics for linear predictor
metrics = evaluate(linear_predictor, 
                   test_features.astype('float32'), 
                   test_labels, 
                   verbose=True) # verbose means we'll print out the metrics
# Out:
# Metrics for simple, LinearLearner.
#
# prediction (col)    0.0  1.0
# actual (row)
# 0                 85270   23
# 1                    27  123
#
# Recall:     0.820
# Precision:  0.842
# Accuracy:   0.999

# %% [markdown]
# ## Delete the Endpoint
#
# I've added a convenience function to delete prediction endpoints after we're done with them. And if you're done evaluating the model, you should delete your model endpoint!

# %%
# Deletes a precictor.endpoint
def delete_endpoint(predictor):
        try:
            boto3.client('sagemaker').delete_endpoint(EndpointName=predictor.endpoint)
            print('Deleted {}'.format(predictor.endpoint))
        except:
            print('Already deleted: {}'.format(predictor.endpoint))

# %%
# delete the predictor endpoint 
delete_endpoint(linear_predictor)
# Out:
# Deleted linear-learner-2019-11-30-14-29-58-648

# %% [markdown]
# ---
#
# # Model Improvements
#
# The default LinearLearner got a high accuracy, but still classified fraudulent and valid data points incorrectly. Specifically classifying more than 30 points as false negatives (incorrectly labeled, fraudulent transactions), and a little over 30 points as false positives (incorrectly labeled, valid transactions). Let's think about what, during training, could cause this behavior and what we could improve.
#
# **1. Model optimization**
# * If we imagine that we are designing this model for use in a bank application, we know that users do *not* want any valid transactions to be categorized as fraudulent. That is, we want to have as few **false positives** (0s classified as 1s) as possible.
# * On the other hand, if our bank manager asks for an application that will catch almost *all* cases of fraud, even if it means a higher number of false positives, then we'd want as few **false negatives** as possible.
# * To train according to specific product demands and goals, we do not want to optimize for accuracy only. Instead, we want to optimize for a metric that can help us decrease the number of false positives or negatives.
#
# <img src='notebook_ims/precision_recall.png' width=40% />
#
# In this notebook, we'll look at different cases for tuning a model and make an optimization decision, accordingly.
#
# **2. Imbalanced training data**
# * At the start of this notebook, we saw that only about 0.17% of the training data was labeled as fraudulent. So, even if a model labels **all** of our data as valid, it will still have a high accuracy.
# * This may result in some overfitting towards valid data, which accounts for some **false negatives**; cases in which fraudulent data (1) is incorrectly characterized as valid (0).
#
# So, let's address these issues in order; first, tuning our model and optimizing for a specific metric during training, and second, accounting for class imbalance in the training set.

# %% [markdown]
# ## Improvement: Model Tuning
#
# Optimizing according to a specific metric is called **model tuning**, and SageMaker provides a number of ways to automatically tune a model.
#
#
# ### Create a LinearLearner and tune for higher precision
#
# **Scenario:**
# * A bank has asked you to build a model that detects cases of fraud with an accuracy of about 85%.
#
# In this case, we want to build a model that has as many true positives and as few false negatives, as possible. This corresponds to a model with a high **recall**: true positives / (true positives + false negatives).
#
# To aim for a specific metric, LinearLearner offers the hyperparameter `binary_classifier_model_selection_criteria`, which is the model evaluation criteria for the training dataset. A reference to this parameter is in [LinearLearner's documentation](https://sagemaker.readthedocs.io/en/stable/linear_learner.html#sagemaker.LinearLearner). We'll also have to further specify the exact value we want to aim for; read more about the details of the parameters, [here](https://docs.aws.amazon.com/sagemaker/latest/dg/ll_hyperparameters.html).
#
# I will assume that performance on a training set will be within about 5% of the performance on a test set. So, for a recall of about 85%, I'll aim for a bit higher, 90%.

# %%
# instantiate a LinearLearner
# tune the model for a higher recall
linear_recall = LinearLearner(role=role,
                              train_instance_count=1, 
                              train_instance_type='ml.c4.xlarge',
                              predictor_type='binary_classifier',
                              output_path=output_path,
                              sagemaker_session=sagemaker_session,
                              epochs=15,
                              binary_classifier_model_selection_criteria='precision_at_target_recall', # target recall
                              target_recall=0.9) # 90% recall

# %% [markdown]
# ### Train the tuned estimator
#
# Fit the new, tuned estimator on the formatted training data.

# %%
# %%time 
# train the estimator on formatted training data
linear_recall.fit(formatted_train_data)
# Out:
# 2019-11-30 15:24:01 Starting - Starting the training job...
# 2019-11-30 15:24:30 Starting - Launching requested ML instances......
# 2019-11-30 15:25:31 Starting - Preparing the instances for training.........
# 2019-11-30 15:26:53 Downloading - Downloading input data
# 2019-11-30 15:26:53 Training - Downloading the training image..Docker entrypoint called with argument(s): train
# [11/30/2019 15:27:08 INFO 140520926431040] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [11/30/2019 15:27:08 INFO 140520926431040] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'predictor_type': u'binary_classifier', u'binary_classifier_model_selection_criteria': u'precision_at_target_recall', u'epochs': u'15', u'feature_dim': u'30', u'target_recall': u'0.9', u'mini_batch_size': u'1000'}
# [11/30/2019 15:27:08 INFO 140520926431040] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'30', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.9', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'precision_at_target_recall', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'binary_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [11/30/2019 15:27:08 WARNING 140520926431040] Loggers have already been setup.
# Process 1 is a worker.
# [11/30/2019 15:27:08 INFO 140520926431040] Using default worker.
# [2019-11-30 15:27:08.831] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 21, "num_examples": 1, "num_bytes": 168000}
# [11/30/2019 15:27:08 INFO 140520926431040] Create Store: local
# [2019-11-30 15:27:08.877] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 45, "num_examples": 11, "num_bytes": 1848000}
# [11/30/2019 15:27:08 INFO 140520926431040] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7fcd3e688050>
# [11/30/2019 15:27:08 INFO 140520926431040] Scaling model computed with parameters:
#  {'stdev_weight':
# [4.7562535e+04 1.9419131e+00 1.6394308e+00 1.4789869e+00 1.4170419e+00
#  1.3764122e+00 1.3037390e+00 1.2100444e+00 1.1044248e+00 1.0992875e+00
#  1.0769122e+00 1.0212113e+00 1.0144311e+00 9.9730700e-01 9.6627188e-01
#  9.0953732e-01 8.7584490e-01 8.5975999e-01 8.4108406e-01 8.0306906e-01
#  7.6150602e-01 7.0069093e-01 7.2143131e-01 6.8534207e-01 5.9842288e-01
#  5.2408093e-01 4.8172125e-01 3.9511588e-01 3.1953603e-01 2.4329514e+02]
# <NDArray 30 @cpu(0)>, 'stdev_label': None, 'mean_label': None, 'mean_weight':
# [ 9.4516172e+04  1.3381084e-02 -1.8507825e-02  3.0525655e-03
#   1.2956868e-02  3.7997791e-03 -2.6551291e-02  1.1056175e-02
#   1.0034550e-03 -3.9743842e-03  1.7335627e-02  2.0118803e-02
#  -5.0890758e-03 -1.4744978e-02  1.0867137e-02  1.8783055e-02
#  -4.3995297e-03 -1.2560965e-02  1.2526816e-03 -4.9423994e-03
#  -7.0784549e-04  1.9289013e-03 -5.4737069e-03 -3.7858561e-03
#   6.4815176e-03  1.0366203e-03 -3.8535960e-03  3.3881629e-04
#  -3.2593647e-03  8.9556389e+01]
# <NDArray 30 @cpu(0)>}
# [11/30/2019 15:27:08 INFO 140520926431040] nvidia-smi took: 0.0252029895782 secs to identify 0 gpus
# [11/30/2019 15:27:08 INFO 140520926431040] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 11, "sum": 11.0, "min": 11}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 12, "sum": 12.0, "min": 12}, "Total Records Seen": {"count": 1, "max": 12000, "sum": 12000.0, "min": 12000}, "Max Records Seen Between Resets": {"count": 1, "max": 11000, "sum": 11000.0, "min": 11000}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1575127628.975884, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1575127628.975848}
#
# [2019-11-30 15:27:14.934] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 3, "duration": 5958, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12039151530050153, "sum": 0.12039151530050153, "min": 0.12039151530050153}}, "EndTime": 1575127634.934687, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575127634.934586}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.11771335538547842, "sum": 0.11771335538547842, "min": 0.11771335538547842}}, "EndTime": 1575127634.934779, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575127634.934759}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12018937216332211, "sum": 0.12018937216332211, "min": 0.12018937216332211}}, "EndTime": 1575127634.934839, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575127634.934822}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.11785709756822442, "sum": 0.11785709756822442, "min": 0.11785709756822442}}, "EndTime": 1575127634.934899, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575127634.934882}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01197232484473056, "sum": 0.01197232484473056, "min": 0.01197232484473056}}, "EndTime": 1575127634.934956, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575127634.934943}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012159458306678875, "sum": 0.012159458306678875, "min": 0.012159458306678875}}, "EndTime": 1575127634.935017, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575127634.934999}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012019407902193729, "sum": 0.012019407902193729, "min": 0.012019407902193729}}, "EndTime": 1575127634.935079, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575127634.935062}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012204848474406418, "sum": 0.012204848474406418, "min": 0.012204848474406418}}, "EndTime": 1575127634.935142, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575127634.935125}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12025535559534427, "sum": 0.12025535559534427, "min": 0.12025535559534427}}, "EndTime": 1575127634.9352, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575127634.935184}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.11789778363405161, "sum": 0.11789778363405161, "min": 0.11789778363405161}}, "EndTime": 1575127634.935261, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575127634.935244}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12052344780351648, "sum": 0.12052344780351648, "min": 0.12052344780351648}}, "EndTime": 1575127634.935329, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575127634.935312}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.11785323669203562, "sum": 0.11785323669203562, "min": 0.11785323669203562}}, "EndTime": 1575127634.935389, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575127634.935371}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012407330562814546, "sum": 0.012407330562814546, "min": 0.012407330562814546}}, "EndTime": 1575127634.93545, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575127634.935432}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012418608560446819, "sum": 0.012418608560446819, "min": 0.012418608560446819}}, "EndTime": 1575127634.935511, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575127634.935493}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012372780443304896, "sum": 0.012372780443304896, "min": 0.012372780443304896}}, "EndTime": 1575127634.93557, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575127634.935553}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012400345452803763, "sum": 0.012400345452803763, "min": 0.012400345452803763}}, "EndTime": 1575127634.935629, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575127634.935613}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12286524334624783, "sum": 0.12286524334624783, "min": 0.12286524334624783}}, "EndTime": 1575127634.935688, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575127634.935671}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12013056315129726, "sum": 0.12013056315129726, "min": 0.12013056315129726}}, "EndTime": 1575127634.935749, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575127634.935731}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12281411619521865, "sum": 0.12281411619521865, "min": 0.12281411619521865}}, "EndTime": 1575127634.93581, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575127634.935793}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12023997611616125, "sum": 0.12023997611616125, "min": 0.12023997611616125}}, "EndTime": 1575127634.935868, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575127634.935853}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.019245207889707544, "sum": 0.019245207889707544, "min": 0.019245207889707544}}, "EndTime": 1575127634.935925, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575127634.935909}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.019225559146223058, "sum": 0.019225559146223058, "min": 0.019225559146223058}}, "EndTime": 1575127634.935981, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575127634.935968}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0193331496617827, "sum": 0.0193331496617827, "min": 0.0193331496617827}}, "EndTime": 1575127634.936036, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575127634.936022}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.019189038681699404, "sum": 0.019189038681699404, "min": 0.019189038681699404}}, "EndTime": 1575127634.936095, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575127634.936078}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12358542502705176, "sum": 0.12358542502705176, "min": 0.12358542502705176}}, "EndTime": 1575127634.936155, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575127634.936138}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.1209360273447468, "sum": 0.1209360273447468, "min": 0.1209360273447468}}, "EndTime": 1575127634.936202, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575127634.936188}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12359863848662257, "sum": 0.12359863848662257, "min": 0.12359863848662257}}, "EndTime": 1575127634.93626, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575127634.936243}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.1210221508543695, "sum": 0.1210221508543695, "min": 0.1210221508543695}}, "EndTime": 1575127634.936316, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575127634.9363}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.02037446887873525, "sum": 0.02037446887873525, "min": 0.02037446887873525}}, "EndTime": 1575127634.936372, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575127634.936359}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.020265791257721696, "sum": 0.020265791257721696, "min": 0.020265791257721696}}, "EndTime": 1575127634.936427, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575127634.936411}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.020324314718832025, "sum": 0.020324314718832025, "min": 0.020324314718832025}}, "EndTime": 1575127634.936492, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575127634.936475}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.02028344818133505, "sum": 0.02028344818133505, "min": 0.02028344818133505}}, "EndTime": 1575127634.936559, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575127634.936542}
#
# [11/30/2019 15:27:14 INFO 140520926431040] #quality_metric: host=algo-1, epoch=0, train binary_classification_cross_entropy_objective <loss>=0.120391515301
# [11/30/2019 15:27:14 INFO 140520926431040] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=binary_classification_cross_entropy_objective, value=0.0119723248447
# [11/30/2019 15:27:14 INFO 140520926431040] Epoch 0: Loss improved. Updating best model
# [11/30/2019 15:27:14 INFO 140520926431040] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 212, "sum": 212.0, "min": 212}, "Total Records Seen": {"count": 1, "max": 211364, "sum": 211364.0, "min": 211364}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1575127634.939909, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575127628.976076}
#
# [11/30/2019 15:27:14 INFO 140520926431040] #throughput_metric: host=algo-1, train throughput=33428.2589511 records/second
#
# 2019-11-30 15:27:06 Training - Training image download completed. Training in progress.[2019-11-30 15:27:21.434] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 5, "duration": 6492, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.016969395532080874, "sum": 0.016969395532080874, "min": 0.016969395532080874}}, "EndTime": 1575127641.434197, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575127641.434093}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.014977266637524168, "sum": 0.014977266637524168, "min": 0.014977266637524168}}, "EndTime": 1575127641.434311, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575127641.434289}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.016949372190925942, "sum": 0.016949372190925942, "min": 0.016949372190925942}}, "EndTime": 1575127641.434381, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575127641.434362}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.014984472842671763, "sum": 0.014984472842671763, "min": 0.014984472842671763}}, "EndTime": 1575127641.434446, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575127641.434427}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.00552600337842002, "sum": 0.00552600337842002, "min": 0.00552600337842002}}, "EndTime": 1575127641.434512, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575127641.434492}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005673934675341275, "sum": 0.005673934675341275, "min": 0.005673934675341275}}, "EndTime": 1575127641.434576, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575127641.434558}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005705727836294989, "sum": 0.005705727836294989, "min": 0.005705727836294989}}, "EndTime": 1575127641.434639, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575127641.434621}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005818209761276317, "sum": 0.005818209761276317, "min": 0.005818209761276317}}, "EndTime": 1575127641.434705, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575127641.434687}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01709679662043126, "sum": 0.01709679662043126, "min": 0.01709679662043126}}, "EndTime": 1575127641.434769, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575127641.434751}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01514430743845264, "sum": 0.01514430743845264, "min": 0.01514430743845264}}, "EndTime": 1575127641.43483, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575127641.434812}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01711446689720729, "sum": 0.01711446689720729, "min": 0.01711446689720729}}, "EndTime": 1575127641.434903, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575127641.434886}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.015140683413749963, "sum": 0.015140683413749963, "min": 0.015140683413749963}}, "EndTime": 1575127641.434965, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575127641.434946}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005646488348293544, "sum": 0.005646488348293544, "min": 0.005646488348293544}}, "EndTime": 1575127641.435026, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575127641.435009}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005781282727892075, "sum": 0.005781282727892075, "min": 0.005781282727892075}}, "EndTime": 1575127641.435086, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575127641.435068}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005621304786534765, "sum": 0.005621304786534765, "min": 0.005621304786534765}}, "EndTime": 1575127641.435146, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575127641.435128}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005837889191643078, "sum": 0.005837889191643078, "min": 0.005837889191643078}}, "EndTime": 1575127641.435205, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575127641.435187}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.02111296484578195, "sum": 0.02111296484578195, "min": 0.02111296484578195}}, "EndTime": 1575127641.435272, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575127641.435255}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.019343205174010003, "sum": 0.019343205174010003, "min": 0.019343205174010003}}, "EndTime": 1575127641.435333, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575127641.435316}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.021103215035481668, "sum": 0.021103215035481668, "min": 0.021103215035481668}}, "EndTime": 1575127641.435396, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575127641.435379}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.019339384510289485, "sum": 0.019339384510289485, "min": 0.019339384510289485}}, "EndTime": 1575127641.435457, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575127641.435441}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011609725556780944, "sum": 0.011609725556780944, "min": 0.011609725556780944}}, "EndTime": 1575127641.435512, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575127641.435496}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011572670761065268, "sum": 0.011572670761065268, "min": 0.011572670761065268}}, "EndTime": 1575127641.435568, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575127641.435552}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011598840198325152, "sum": 0.011598840198325152, "min": 0.011598840198325152}}, "EndTime": 1575127641.435621, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575127641.435605}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011567359885378698, "sum": 0.011567359885378698, "min": 0.011567359885378698}}, "EndTime": 1575127641.435669, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575127641.435656}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.021972029590127454, "sum": 0.021972029590127454, "min": 0.021972029590127454}}, "EndTime": 1575127641.435717, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575127641.435705}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.020189454327875646, "sum": 0.020189454327875646, "min": 0.020189454327875646}}, "EndTime": 1575127641.435764, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575127641.435751}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.021967956538176417, "sum": 0.021967956538176417, "min": 0.021967956538176417}}, "EndTime": 1575127641.43581, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575127641.435798}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.020193388613025148, "sum": 0.020193388613025148, "min": 0.020193388613025148}}, "EndTime": 1575127641.435851, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575127641.43584}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012634582919092035, "sum": 0.012634582919092035, "min": 0.012634582919092035}}, "EndTime": 1575127641.435891, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575127641.43588}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01264003279700351, "sum": 0.01264003279700351, "min": 0.01264003279700351}}, "EndTime": 1575127641.435931, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575127641.43592}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012633892729653784, "sum": 0.012633892729653784, "min": 0.012633892729653784}}, "EndTime": 1575127641.435982, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575127641.435967}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012640807738256215, "sum": 0.012640807738256215, "min": 0.012640807738256215}}, "EndTime": 1575127641.436039, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575127641.436024}
#
# [11/30/2019 15:27:21 INFO 140520926431040] #quality_metric: host=algo-1, epoch=1, train binary_classification_cross_entropy_objective <loss>=0.0169693955321
# [11/30/2019 15:27:21 INFO 140520926431040] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=binary_classification_cross_entropy_objective, value=0.00552600337842
# [11/30/2019 15:27:21 INFO 140520926431040] Epoch 1: Loss improved. Updating best model
# [11/30/2019 15:27:21 INFO 140520926431040] #progress_metric: host=algo-1, completed 13 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 412, "sum": 412.0, "min": 412}, "Total Records Seen": {"count": 1, "max": 410728, "sum": 410728.0, "min": 410728}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 1575127641.439529, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575127634.941456}
#
# [11/30/2019 15:27:21 INFO 140520926431040] #throughput_metric: host=algo-1, train throughput=30679.9326465 records/second
# [2019-11-30 15:27:27.896] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 7, "duration": 6452, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.010348244918650717, "sum": 0.010348244918650717, "min": 0.010348244918650717}}, "EndTime": 1575127647.896719, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575127647.896594}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.008784410117259576, "sum": 0.008784410117259576, "min": 0.008784410117259576}}, "EndTime": 1575127647.896833, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575127647.89681}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.010337603458807097, "sum": 0.010337603458807097, "min": 0.010337603458807097}}, "EndTime": 1575127647.896903, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575127647.896883}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.00879288740014311, "sum": 0.00879288740014311, "min": 0.00879288740014311}}, "EndTime": 1575127647.896971, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575127647.896951}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.00515218499991762, "sum": 0.00515218499991762, "min": 0.00515218499991762}}, "EndTime": 1575127647.897043, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575127647.897023}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005908446442541765, "sum": 0.005908446442541765, "min": 0.005908446442541765}}, "EndTime": 1575127647.897106, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575127647.897088}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.004875644699113453, "sum": 0.004875644699113453, "min": 0.004875644699113453}}, "EndTime": 1575127647.897151, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575127647.897137}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.006169507622718811, "sum": 0.006169507622718811, "min": 0.006169507622718811}}, "EndTime": 1575127647.897209, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575127647.897192}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.010584099244831795, "sum": 0.010584099244831795, "min": 0.010584099244831795}}, "EndTime": 1575127647.89727, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575127647.897253}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.009069185371974006, "sum": 0.009069185371974006, "min": 0.009069185371974006}}, "EndTime": 1575127647.897329, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575127647.897312}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.010593148212337014, "sum": 0.010593148212337014, "min": 0.010593148212337014}}, "EndTime": 1575127647.897379, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575127647.897368}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.00906779259053906, "sum": 0.00906779259053906, "min": 0.00906779259053906}}, "EndTime": 1575127647.897409, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575127647.897402}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005506083292877255, "sum": 0.005506083292877255, "min": 0.005506083292877255}}, "EndTime": 1575127647.897448, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575127647.89744}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005794105320120577, "sum": 0.005794105320120577, "min": 0.005794105320120577}}, "EndTime": 1575127647.897474, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575127647.897467}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0055286677099352505, "sum": 0.0055286677099352505, "min": 0.0055286677099352505}}, "EndTime": 1575127647.897515, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575127647.897501}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005800566334820273, "sum": 0.005800566334820273, "min": 0.005800566334820273}}, "EndTime": 1575127647.897553, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575127647.897545}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.015302359382111823, "sum": 0.015302359382111823, "min": 0.015302359382111823}}, "EndTime": 1575127647.897608, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575127647.897592}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.014092539535694984, "sum": 0.014092539535694984, "min": 0.014092539535694984}}, "EndTime": 1575127647.89767, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575127647.897653}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.015297143684559731, "sum": 0.015297143684559731, "min": 0.015297143684559731}}, "EndTime": 1575127647.89773, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575127647.897714}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.014089563525501806, "sum": 0.014089563525501806, "min": 0.014089563525501806}}, "EndTime": 1575127647.897788, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575127647.897772}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011626854907927201, "sum": 0.011626854907927201, "min": 0.011626854907927201}}, "EndTime": 1575127647.897845, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575127647.897829}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011600148936611923, "sum": 0.011600148936611923, "min": 0.011600148936611923}}, "EndTime": 1575127647.897903, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575127647.897886}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01162714082811346, "sum": 0.01162714082811346, "min": 0.01162714082811346}}, "EndTime": 1575127647.897962, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575127647.897945}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011601483150942242, "sum": 0.011601483150942242, "min": 0.011601483150942242}}, "EndTime": 1575127647.898024, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575127647.898007}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.016180053617487002, "sum": 0.016180053617487002, "min": 0.016180053617487002}}, "EndTime": 1575127647.898091, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575127647.898073}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.014949429988861083, "sum": 0.014949429988861083, "min": 0.014949429988861083}}, "EndTime": 1575127647.898148, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575127647.898133}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.016178322720168226, "sum": 0.016178322720168226, "min": 0.016178322720168226}}, "EndTime": 1575127647.898209, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575127647.898193}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.014950412340499647, "sum": 0.014950412340499647, "min": 0.014950412340499647}}, "EndTime": 1575127647.898271, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575127647.898254}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012637379995542555, "sum": 0.012637379995542555, "min": 0.012637379995542555}}, "EndTime": 1575127647.898338, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575127647.898321}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01264617766147882, "sum": 0.01264617766147882, "min": 0.01264617766147882}}, "EndTime": 1575127647.898401, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575127647.898384}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012637155402844874, "sum": 0.012637155402844874, "min": 0.012637155402844874}}, "EndTime": 1575127647.898468, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575127647.89845}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012646453793324419, "sum": 0.012646453793324419, "min": 0.012646453793324419}}, "EndTime": 1575127647.898528, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575127647.898512}
#
# [11/30/2019 15:27:27 INFO 140520926431040] #quality_metric: host=algo-1, epoch=2, train binary_classification_cross_entropy_objective <loss>=0.0103482449187
# [11/30/2019 15:27:27 INFO 140520926431040] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=binary_classification_cross_entropy_objective, value=0.00487564469911
# [11/30/2019 15:27:27 INFO 140520926431040] Epoch 2: Loss improved. Updating best model
# [11/30/2019 15:27:27 INFO 140520926431040] #progress_metric: host=algo-1, completed 20 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 612, "sum": 612.0, "min": 612}, "Total Records Seen": {"count": 1, "max": 610092, "sum": 610092.0, "min": 610092}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1575127647.901166, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575127641.441554}
#
# [11/30/2019 15:27:27 INFO 140520926431040] #throughput_metric: host=algo-1, train throughput=30862.5132046 records/second
# [2019-11-30 15:27:34.060] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 9, "duration": 6157, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.008081253375240308, "sum": 0.008081253375240308, "min": 0.008081253375240308}}, "EndTime": 1575127654.060523, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1575127654.060423}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.006758862757802609, "sum": 0.006758862757802609, "min": 0.006758862757802609}}, "EndTime": 1575127654.060636, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1575127654.060614}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.008074789979350027, "sum": 0.008074789979350027, "min": 0.008074789979350027}}, "EndTime": 1575127654.060724, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1575127654.06068}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0067693622867066655, "sum": 0.0067693622867066655, "min": 0.0067693622867066655}}, "EndTime": 1575127654.060794, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1575127654.060773}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.00539260755187303, "sum": 0.00539260755187303, "min": 0.00539260755187303}}, "EndTime": 1575127654.060869, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1575127654.060849}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.00602745162976447, "sum": 0.00602745162976447, "min": 0.00602745162976447}}, "EndTime": 1575127654.060937, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1575127654.060918}
#
# ...
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.004969085457936004, "sum": 0.004969085457936004, "min": 0.004969085457936004}}, "EndTime": 1575127721.385582, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575127721.38557}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.004406221224435011, "sum": 0.004406221224435011, "min": 0.004406221224435011}}, "EndTime": 1575127721.385645, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575127721.385621}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.004328785008671295, "sum": 0.004328785008671295, "min": 0.004328785008671295}}, "EndTime": 1575127721.385696, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575127721.385681}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005189709287342714, "sum": 0.005189709287342714, "min": 0.005189709287342714}}, "EndTime": 1575127721.385758, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575127721.385741}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.004275904138932875, "sum": 0.004275904138932875, "min": 0.004275904138932875}}, "EndTime": 1575127721.385808, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575127721.385792}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005457811859684374, "sum": 0.005457811859684374, "min": 0.005457811859684374}}, "EndTime": 1575127721.385858, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575127721.385842}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0056210523526273185, "sum": 0.0056210523526273185, "min": 0.0056210523526273185}}, "EndTime": 1575127721.385909, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575127721.385898}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005208641045357115, "sum": 0.005208641045357115, "min": 0.005208641045357115}}, "EndTime": 1575127721.385941, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575127721.385932}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0056220256066202515, "sum": 0.0056220256066202515, "min": 0.0056220256066202515}}, "EndTime": 1575127721.385994, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575127721.385978}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005208613157272339, "sum": 0.005208613157272339, "min": 0.005208613157272339}}, "EndTime": 1575127721.38606, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575127721.386044}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005202507362892879, "sum": 0.005202507362892879, "min": 0.005202507362892879}}, "EndTime": 1575127721.386104, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575127721.386095}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0056462764587234615, "sum": 0.0056462764587234615, "min": 0.0056462764587234615}}, "EndTime": 1575127721.386151, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575127721.386137}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005202798390508297, "sum": 0.005202798390508297, "min": 0.005202798390508297}}, "EndTime": 1575127721.386204, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575127721.386188}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005646713791330855, "sum": 0.005646713791330855, "min": 0.005646713791330855}}, "EndTime": 1575127721.386259, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575127721.386244}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011820130315857318, "sum": 0.011820130315857318, "min": 0.011820130315857318}}, "EndTime": 1575127721.386298, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575127721.386284}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011742516425985786, "sum": 0.011742516425985786, "min": 0.011742516425985786}}, "EndTime": 1575127721.386353, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575127721.386337}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011819988891706993, "sum": 0.011819988891706993, "min": 0.011819988891706993}}, "EndTime": 1575127721.386422, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575127721.386404}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011742443491466081, "sum": 0.011742443491466081, "min": 0.011742443491466081}}, "EndTime": 1575127721.386492, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575127721.386474}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01176092544812054, "sum": 0.01176092544812054, "min": 0.01176092544812054}}, "EndTime": 1575127721.386561, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575127721.386543}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01170222332010317, "sum": 0.01170222332010317, "min": 0.01170222332010317}}, "EndTime": 1575127721.386621, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575127721.386605}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011760883974070525, "sum": 0.011760883974070525, "min": 0.011760883974070525}}, "EndTime": 1575127721.386687, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575127721.386671}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011701884652801494, "sum": 0.011701884652801494, "min": 0.011701884652801494}}, "EndTime": 1575127721.386751, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575127721.386735}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012695249255578123, "sum": 0.012695249255578123, "min": 0.012695249255578123}}, "EndTime": 1575127721.386807, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575127721.38679}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012618273330094227, "sum": 0.012618273330094227, "min": 0.012618273330094227}}, "EndTime": 1575127721.386858, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575127721.386843}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012695356130599975, "sum": 0.012695356130599975, "min": 0.012695356130599975}}, "EndTime": 1575127721.386917, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575127721.3869}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012618582938783733, "sum": 0.012618582938783733, "min": 0.012618582938783733}}, "EndTime": 1575127721.386986, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575127721.386968}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012624074699890674, "sum": 0.012624074699890674, "min": 0.012624074699890674}}, "EndTime": 1575127721.387048, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575127721.387032}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01271719395635116, "sum": 0.01271719395635116, "min": 0.01271719395635116}}, "EndTime": 1575127721.387116, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575127721.387099}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012624760339008504, "sum": 0.012624760339008504, "min": 0.012624760339008504}}, "EndTime": 1575127721.387175, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575127721.387159}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012718501103882814, "sum": 0.012718501103882814, "min": 0.012718501103882814}}, "EndTime": 1575127721.387227, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575127721.387216}
#
# [11/30/2019 15:28:41 INFO 140520926431040] #quality_metric: host=algo-1, epoch=14, train binary_classification_cross_entropy_objective <loss>=0.00496976886443
# [11/30/2019 15:28:41 INFO 140520926431040] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=binary_classification_cross_entropy_objective, value=0.00427590413893
# [11/30/2019 15:28:41 INFO 140520926431040] Epoch 14: Loss improved. Updating best model
# [11/30/2019 15:28:41 INFO 140520926431040] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 3012, "sum": 3012.0, "min": 3012}, "Total Records Seen": {"count": 1, "max": 3002460, "sum": 3002460.0, "min": 3002460}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 17, "sum": 17.0, "min": 17}}, "EndTime": 1575127721.389943, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575127715.485434}
#
# [11/30/2019 15:28:41 INFO 140520926431040] #throughput_metric: host=algo-1, train throughput=33763.9430894 records/second
# [11/30/2019 15:28:41 WARNING 140520926431040] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [11/30/2019 15:28:41 WARNING 140520926431040] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2019-11-30 15:28:41.397] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 33, "duration": 6, "num_examples": 1, "num_bytes": 168000}
# [2019-11-30 15:28:42.043] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 36, "duration": 643, "num_examples": 200, "num_bytes": 33493152}
# [2019-11-30 15:28:42.833] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 38, "duration": 716, "num_examples": 200, "num_bytes": 33493152}
# [11/30/2019 15:28:42 INFO 140520926431040] #train_score (algo-1) : ('binary_classification_cross_entropy_objective', 0.004177055206248553)
# [11/30/2019 15:28:42 INFO 140520926431040] #train_score (algo-1) : ('binary_classification_accuracy', 0.9499107160771253)
# [11/30/2019 15:28:42 INFO 140520926431040] #train_score (algo-1) : ('binary_f_1.000', 0.05827989437947944)
# [11/30/2019 15:28:42 INFO 140520926431040] #train_score (algo-1) : ('precision', 0.030111089456246347)
# [11/30/2019 15:28:42 INFO 140520926431040] #train_score (algo-1) : ('recall', 0.9035087719298246)
# [11/30/2019 15:28:42 INFO 140520926431040] #quality_metric: host=algo-1, train binary_classification_cross_entropy_objective <loss>=0.00417705520625
# [11/30/2019 15:28:42 INFO 140520926431040] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.949910716077
# [11/30/2019 15:28:42 INFO 140520926431040] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.0582798943795
# [11/30/2019 15:28:42 INFO 140520926431040] #quality_metric: host=algo-1, train precision <score>=0.0301110894562
# [11/30/2019 15:28:42 INFO 140520926431040] #quality_metric: host=algo-1, train recall <score>=0.90350877193
# [11/30/2019 15:28:42 INFO 140520926431040] Best model found for hyperparameters: {"lr_scheduler_step": 10, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.1, "lr_scheduler_minimum_lr": 0.0001}
# [11/30/2019 15:28:42 INFO 140520926431040] Saved checkpoint to "/tmp/tmpWewipZ/mx-mod-0000.params"
# [11/30/2019 15:28:42 INFO 140520926431040] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 94111.7959022522, "sum": 94111.7959022522, "min": 94111.7959022522}, "finalize.time": {"count": 1, "max": 1445.063829421997, "sum": 1445.063829421997, "min": 1445.063829421997}, "initialize.time": {"count": 1, "max": 160.93802452087402, "sum": 160.93802452087402, "min": 160.93802452087402}, "check_early_stopping.time": {"count": 15, "max": 0.9260177612304688, "sum": 10.485410690307617, "min": 0.19884109497070312}, "setuptime": {"count": 1, "max": 25.84099769592285, "sum": 25.84099769592285, "min": 25.84099769592285}, "update.time": {"count": 15, "max": 6497.910976409912, "sum": 92388.9639377594, "min": 5563.129901885986}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1575127722.844365, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1575127628.80945}
#
#
# 2019-11-30 15:28:55 Uploading - Uploading generated training model
# 2019-11-30 15:28:55 Completed - Training job completed
# Training seconds: 139
# Billable seconds: 139
# CPU times: user 713 ms, sys: 62.4 ms, total: 775 ms
# Wall time: 5min 13s

# %% [markdown]
# ### Deploy and evaluate the tuned estimator
#
# Deploy the tuned predictor and evaluate it.
#
# We hypothesized that a tuned model, optimized for a higher recall, would have fewer false negatives (fraudulent transactions incorrectly labeled as valid); did the number of false negatives get reduced after tuning the model?

# %%
# %%time 
# deploy and create a predictor
recall_predictor = linear_recall.deploy(initial_instance_count=1, instance_type='ml.t2.medium')
# Out:
# --------------------------------------------------------------------------------------------------------------------------------------!CPU times: user 717 ms, sys: 15.1 ms, total: 732 ms
# Wall time: 11min 16s

# %%
print('Metrics for tuned (recall), LinearLearner.\n')

# get metrics for tuned predictor
metrics = evaluate(recall_predictor, 
                   test_features.astype('float32'), 
                   test_labels, 
                   verbose=True)
# Out:
# Metrics for tuned (recall), LinearLearner.
#
# prediction (col)    0.0   1.0
# actual (row)
# 0                 81037  4256
# 1                     9   141
#
# Recall:     0.940
# Precision:  0.032
# Accuracy:   0.950

# %% [markdown]
# ## Delete the endpoint
#
# As always, when you're done evaluating a model, you should delete the endpoint. Below, I'm using the `delete_endpoint` helper function I defined earlier.

# %%
# delete the predictor endpoint 
delete_endpoint(recall_predictor)
# Out:
# Deleted linear-learner-2019-11-30-15-24-01-697

# %% [markdown]
# ---
# ## Improvement: Managing Class Imbalance
#
# We have a model that is tuned to get a higher recall, which aims to reduce the number of false negatives. Earlier, we discussed how class imbalance may actually bias our model towards predicting that all transactions are valid, resulting in higher false negatives and true negatives. It stands to reason that this model could be further improved if we account for this imbalance.
#
# To account for class imbalance during training of a binary classifier, LinearLearner offers the hyperparameter, `positive_example_weight_mult`, which is the weight assigned to positive (1, fraudulent) examples when training a binary classifier. The weight of negative examples (0, valid) is fixed at 1.
#
# ### EXERCISE: Create a LinearLearner with a `positive_example_weight_mult` parameter
#
# In **addition** to tuning a model for higher recall (you may use `linear_recall` as a starting point), you should *add* a parameter that helps account for class imbalance. From the [hyperparameter documentation](https://docs.aws.amazon.com/sagemaker/latest/dg/ll_hyperparameters.html) on `positive_example_weight_mult`, it reads:
# > "If you want the algorithm to choose a weight so that errors in classifying negative vs. positive examples have equal impact on training loss, specify `balanced`."
#
# You could also put in a specific float value, in which case you'd want to weight positive examples more heavily than negative examples, since there are fewer of them.

# %%
# instantiate a LinearLearner

# include params for tuning for higher recall
# *and* account for class imbalance in training data
linear_balanced = LinearLearner(role=role,
                              train_instance_count=1, 
                              train_instance_type='ml.c4.xlarge',
                              predictor_type='binary_classifier',
                              output_path=output_path,
                              sagemaker_session=sagemaker_session,
                              epochs=15,
                              binary_classifier_model_selection_criteria='precision_at_target_recall', # target recall
                              positive_example_weight_mult='balanced',
                              target_recall=0.9) # 90% recall

# %% [markdown]
# ### EXERCISE: Train the balanced estimator
#
# Fit the new, balanced estimator on the formatted training data.

# %%
# %%time 
# train the estimator on formatted training data
linear_balanced.fit(formatted_train_data)
# Out:
# 2019-11-30 15:40:44 Starting - Starting the training job...
# 2019-11-30 15:41:14 Starting - Launching requested ML instances.........
# 2019-11-30 15:42:15 Starting - Preparing the instances for training......
# 2019-11-30 15:43:21 Downloading - Downloading input data...
# 2019-11-30 15:43:46 Training - Downloading the training imageDocker entrypoint called with argument(s): train
# [11/30/2019 15:44:01 INFO 139723401512768] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [11/30/2019 15:44:01 INFO 139723401512768] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'predictor_type': u'binary_classifier', u'feature_dim': u'30', u'binary_classifier_model_selection_criteria': u'precision_at_target_recall', u'epochs': u'15', u'positive_example_weight_mult': u'balanced', u'target_recall': u'0.9', u'mini_batch_size': u'1000'}
# [11/30/2019 15:44:01 INFO 139723401512768] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'30', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.9', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'precision_at_target_recall', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'binary_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'balanced', u'l1': u'auto', u'margin': u'1.0'}
# [11/30/2019 15:44:01 WARNING 139723401512768] Loggers have already been setup.
# Process 1 is a worker.
# [11/30/2019 15:44:01 INFO 139723401512768] Using default worker.
# [2019-11-30 15:44:01.610] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 32, "num_examples": 1, "num_bytes": 168000}
# [11/30/2019 15:44:01 INFO 139723401512768] Create Store: local
# [2019-11-30 15:44:01.675] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 64, "num_examples": 11, "num_bytes": 1848000}
# [11/30/2019 15:44:01 INFO 139723401512768] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f138e5d5610>
# [11/30/2019 15:44:01 INFO 139723401512768] Scaling model computed with parameters:
#  {'stdev_weight':
# [4.7562535e+04 1.9419131e+00 1.6394308e+00 1.4789869e+00 1.4170419e+00
#  1.3764122e+00 1.3037390e+00 1.2100444e+00 1.1044248e+00 1.0992875e+00
#  1.0769122e+00 1.0212113e+00 1.0144311e+00 9.9730700e-01 9.6627188e-01
#  9.0953732e-01 8.7584490e-01 8.5975999e-01 8.4108406e-01 8.0306906e-01
#  7.6150602e-01 7.0069093e-01 7.2143131e-01 6.8534207e-01 5.9842288e-01
#  5.2408093e-01 4.8172125e-01 3.9511588e-01 3.1953603e-01 2.4329514e+02]
# <NDArray 30 @cpu(0)>, 'stdev_label': None, 'mean_label': None, 'mean_weight':
# [ 9.4516172e+04  1.3381084e-02 -1.8507825e-02  3.0525655e-03
#   1.2956868e-02  3.7997791e-03 -2.6551291e-02  1.1056175e-02
#   1.0034550e-03 -3.9743842e-03  1.7335627e-02  2.0118803e-02
#  -5.0890758e-03 -1.4744978e-02  1.0867137e-02  1.8783055e-02
#  -4.3995297e-03 -1.2560965e-02  1.2526816e-03 -4.9423994e-03
#  -7.0784549e-04  1.9289013e-03 -5.4737069e-03 -3.7858561e-03
#   6.4815176e-03  1.0366203e-03 -3.8535960e-03  3.3881629e-04
#  -3.2593647e-03  8.9556389e+01]
# <NDArray 30 @cpu(0)>}
# [11/30/2019 15:44:01 INFO 139723401512768] nvidia-smi took: 0.0252120494843 secs to identify 0 gpus
# [11/30/2019 15:44:01 INFO 139723401512768] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 11, "sum": 11.0, "min": 11}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 12, "sum": 12.0, "min": 12}, "Total Records Seen": {"count": 1, "max": 12000, "sum": 12000.0, "min": 12000}, "Max Records Seen Between Resets": {"count": 1, "max": 11000, "sum": 11000.0, "min": 11000}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1575128641.844207, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1575128641.844167}
#
# [2019-11-30 15:44:08.057] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 3, "duration": 6212, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5198990342796748, "sum": 0.5198990342796748, "min": 0.5198990342796748}}, "EndTime": 1575128648.057469, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575128648.05736}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.43319621564395466, "sum": 0.43319621564395466, "min": 0.43319621564395466}}, "EndTime": 1575128648.057567, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575128648.057547}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.45187936807757045, "sum": 0.45187936807757045, "min": 0.45187936807757045}}, "EndTime": 1575128648.057638, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575128648.057619}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.48156533353412573, "sum": 0.48156533353412573, "min": 0.48156533353412573}}, "EndTime": 1575128648.057703, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575128648.057684}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.45443255355489914, "sum": 0.45443255355489914, "min": 0.45443255355489914}}, "EndTime": 1575128648.057774, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575128648.057756}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4719969323124718, "sum": 0.4719969323124718, "min": 0.4719969323124718}}, "EndTime": 1575128648.057835, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575128648.057818}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.451358473217068, "sum": 0.451358473217068, "min": 0.451358473217068}}, "EndTime": 1575128648.057897, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575128648.05788}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.46753956051927115, "sum": 0.46753956051927115, "min": 0.46753956051927115}}, "EndTime": 1575128648.057963, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575128648.057946}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4467043378053598, "sum": 0.4467043378053598, "min": 0.4467043378053598}}, "EndTime": 1575128648.058025, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575128648.058008}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5134138284807829, "sum": 0.5134138284807829, "min": 0.5134138284807829}}, "EndTime": 1575128648.058096, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575128648.058079}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5029268555760983, "sum": 0.5029268555760983, "min": 0.5029268555760983}}, "EndTime": 1575128648.05815, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575128648.058135}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4959998554632292, "sum": 0.4959998554632292, "min": 0.4959998554632292}}, "EndTime": 1575128648.058202, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575128648.058187}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4386461932599245, "sum": 0.4386461932599245, "min": 0.4386461932599245}}, "EndTime": 1575128648.058237, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575128648.058228}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4555865734234527, "sum": 0.4555865734234527, "min": 0.4555865734234527}}, "EndTime": 1575128648.058263, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575128648.058256}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4459658067597816, "sum": 0.4459658067597816, "min": 0.4459658067597816}}, "EndTime": 1575128648.058295, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575128648.058282}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4606522866349724, "sum": 0.4606522866349724, "min": 0.4606522866349724}}, "EndTime": 1575128648.058349, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575128648.058333}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.550803728266577, "sum": 0.550803728266577, "min": 0.550803728266577}}, "EndTime": 1575128648.058406, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575128648.058389}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4718065330467032, "sum": 0.4718065330467032, "min": 0.4718065330467032}}, "EndTime": 1575128648.058467, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575128648.05845}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.48866629005317114, "sum": 0.48866629005317114, "min": 0.48866629005317114}}, "EndTime": 1575128648.058525, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575128648.058508}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.49325807281954204, "sum": 0.49325807281954204, "min": 0.49325807281954204}}, "EndTime": 1575128648.058584, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575128648.058568}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4759093681795513, "sum": 0.4759093681795513, "min": 0.4759093681795513}}, "EndTime": 1575128648.058645, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575128648.058628}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4731694699963134, "sum": 0.4731694699963134, "min": 0.4731694699963134}}, "EndTime": 1575128648.058699, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575128648.058689}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4797446314749406, "sum": 0.4797446314749406, "min": 0.4797446314749406}}, "EndTime": 1575128648.058741, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575128648.058727}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4727636283031061, "sum": 0.4727636283031061, "min": 0.4727636283031061}}, "EndTime": 1575128648.058789, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575128648.058777}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.9648839267749882, "sum": 0.9648839267749882, "min": 0.9648839267749882}}, "EndTime": 1575128648.058842, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575128648.058827}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.9625357290296699, "sum": 0.9625357290296699, "min": 0.9625357290296699}}, "EndTime": 1575128648.0589, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575128648.058883}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.9876715761117599, "sum": 0.9876715761117599, "min": 0.9876715761117599}}, "EndTime": 1575128648.058955, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575128648.058939}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.9683548965837488, "sum": 0.9683548965837488, "min": 0.9683548965837488}}, "EndTime": 1575128648.059015, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575128648.058999}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.0778882952359454, "sum": 1.0778882952359454, "min": 1.0778882952359454}}, "EndTime": 1575128648.05907, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575128648.059055}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.0759152055289878, "sum": 1.0759152055289878, "min": 1.0759152055289878}}, "EndTime": 1575128648.059125, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575128648.059109}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.082764480284111, "sum": 1.082764480284111, "min": 1.082764480284111}}, "EndTime": 1575128648.059175, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575128648.05916}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.0723594784377208, "sum": 1.0723594784377208, "min": 1.0723594784377208}}, "EndTime": 1575128648.059243, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575128648.059227}
#
# [11/30/2019 15:44:08 INFO 139723401512768] #quality_metric: host=algo-1, epoch=0, train binary_classification_weighted_cross_entropy_objective <loss>=0.51989903428
# [11/30/2019 15:44:08 INFO 139723401512768] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=binary_classification_weighted_cross_entropy_objective, value=0.433196215644
# [11/30/2019 15:44:08 INFO 139723401512768] Epoch 0: Loss improved. Updating best model
# [11/30/2019 15:44:08 INFO 139723401512768] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 212, "sum": 212.0, "min": 212}, "Total Records Seen": {"count": 1, "max": 211364, "sum": 211364.0, "min": 211364}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1575128648.062674, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1575128641.844403}
#
# [11/30/2019 15:44:08 INFO 139723401512768] #throughput_metric: host=algo-1, train throughput=32060.3210765 records/second
# [2019-11-30 15:44:15.353] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 5, "duration": 7289, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.34827062539718856, "sum": 0.34827062539718856, "min": 0.34827062539718856}}, "EndTime": 1575128655.353993, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575128655.353877}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3244977309643923, "sum": 0.3244977309643923, "min": 0.3244977309643923}}, "EndTime": 1575128655.354077, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575128655.354059}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.33362206214636414, "sum": 0.33362206214636414, "min": 0.33362206214636414}}, "EndTime": 1575128655.354134, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575128655.354119}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.33482046359268264, "sum": 0.33482046359268264, "min": 0.33482046359268264}}, "EndTime": 1575128655.354195, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575128655.354179}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.42981629315093534, "sum": 0.42981629315093534, "min": 0.42981629315093534}}, "EndTime": 1575128655.354246, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575128655.35423}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.48580035818282086, "sum": 0.48580035818282086, "min": 0.48580035818282086}}, "EndTime": 1575128655.354282, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575128655.354273}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4389084280291993, "sum": 0.4389084280291993, "min": 0.4389084280291993}}, "EndTime": 1575128655.354311, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575128655.354303}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.48007591853309517, "sum": 0.48007591853309517, "min": 0.48007591853309517}}, "EndTime": 1575128655.354358, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575128655.354343}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.33474248715501337, "sum": 0.33474248715501337, "min": 0.33474248715501337}}, "EndTime": 1575128655.354416, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575128655.3544}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3468805073877076, "sum": 0.3468805073877076, "min": 0.3468805073877076}}, "EndTime": 1575128655.354451, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575128655.354442}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.34343771860707345, "sum": 0.34343771860707345, "min": 0.34343771860707345}}, "EndTime": 1575128655.354479, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575128655.354472}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.34103905655750677, "sum": 0.34103905655750677, "min": 0.34103905655750677}}, "EndTime": 1575128655.354506, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575128655.354498}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4381230466928913, "sum": 0.4381230466928913, "min": 0.4381230466928913}}, "EndTime": 1575128655.354563, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575128655.354538}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4547339693002365, "sum": 0.4547339693002365, "min": 0.4547339693002365}}, "EndTime": 1575128655.354593, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575128655.354585}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4192352713963494, "sum": 0.4192352713963494, "min": 0.4192352713963494}}, "EndTime": 1575128655.354619, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575128655.354612}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4543847779221271, "sum": 0.4543847779221271, "min": 0.4543847779221271}}, "EndTime": 1575128655.354659, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575128655.354648}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4254361819166634, "sum": 0.4254361819166634, "min": 0.4254361819166634}}, "EndTime": 1575128655.354706, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575128655.354692}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4222184012714942, "sum": 0.4222184012714942, "min": 0.4222184012714942}}, "EndTime": 1575128655.354758, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575128655.354742}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.42206250889457053, "sum": 0.42206250889457053, "min": 0.42206250889457053}}, "EndTime": 1575128655.354813, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575128655.354797}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.42253632619273124, "sum": 0.42253632619273124, "min": 0.42253632619273124}}, "EndTime": 1575128655.354869, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575128655.354853}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.45145546523051044, "sum": 0.45145546523051044, "min": 0.45145546523051044}}, "EndTime": 1575128655.354935, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575128655.354917}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.473882604972801, "sum": 0.473882604972801, "min": 0.473882604972801}}, "EndTime": 1575128655.355005, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575128655.354987}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.44941087939391783, "sum": 0.44941087939391783, "min": 0.44941087939391783}}, "EndTime": 1575128655.355072, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575128655.355054}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.47238311575884795, "sum": 0.47238311575884795, "min": 0.47238311575884795}}, "EndTime": 1575128655.355141, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575128655.355123}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.9596137844066523, "sum": 0.9596137844066523, "min": 0.9596137844066523}}, "EndTime": 1575128655.355211, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575128655.355193}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.9621738933007322, "sum": 0.9621738933007322, "min": 0.9621738933007322}}, "EndTime": 1575128655.355277, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575128655.35526}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.9589153466919559, "sum": 0.9589153466919559, "min": 0.9589153466919559}}, "EndTime": 1575128655.355345, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575128655.355327}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.9618234952226955, "sum": 0.9618234952226955, "min": 0.9618234952226955}}, "EndTime": 1575128655.355411, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575128655.355394}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.060545575089191, "sum": 1.060545575089191, "min": 1.060545575089191}}, "EndTime": 1575128655.355472, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575128655.355456}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.0728572885331198, "sum": 1.0728572885331198, "min": 1.0728572885331198}}, "EndTime": 1575128655.355537, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575128655.35552}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.0546580361984483, "sum": 1.0546580361984483, "min": 1.0546580361984483}}, "EndTime": 1575128655.355599, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575128655.355582}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.0699761623976818, "sum": 1.0699761623976818, "min": 1.0699761623976818}}, "EndTime": 1575128655.355659, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575128655.355642}
#
# [11/30/2019 15:44:15 INFO 139723401512768] #quality_metric: host=algo-1, epoch=1, train binary_classification_weighted_cross_entropy_objective <loss>=0.348270625397
# [11/30/2019 15:44:15 INFO 139723401512768] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=binary_classification_weighted_cross_entropy_objective, value=0.324497730964
# [11/30/2019 15:44:15 INFO 139723401512768] Epoch 1: Loss improved. Updating best model
# [11/30/2019 15:44:15 INFO 139723401512768] #progress_metric: host=algo-1, completed 13 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 412, "sum": 412.0, "min": 412}, "Total Records Seen": {"count": 1, "max": 410728, "sum": 410728.0, "min": 410728}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 1575128655.358529, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1575128648.064338}
#
# [11/30/2019 15:44:15 INFO 139723401512768] #throughput_metric: host=algo-1, train throughput=27331.3847984 records/second
# [2019-11-30 15:44:21.133] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 7, "duration": 5773, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.32001723928787, "sum": 0.32001723928787, "min": 0.32001723928787}}, "EndTime": 1575128661.133777, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575128661.133672}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3067641949677587, "sum": 0.3067641949677587, "min": 0.3067641949677587}}, "EndTime": 1575128661.133851, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575128661.133834}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3125156500734875, "sum": 0.3125156500734875, "min": 0.3125156500734875}}, "EndTime": 1575128661.13391, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575128661.133893}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.31196614749467555, "sum": 0.31196614749467555, "min": 0.31196614749467555}}, "EndTime": 1575128661.133957, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575128661.133946}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3972083665186436, "sum": 0.3972083665186436, "min": 0.3972083665186436}}, "EndTime": 1575128661.133989, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575128661.133981}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.46899034027598013, "sum": 0.46899034027598013, "min": 0.46899034027598013}}, "EndTime": 1575128661.134024, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575128661.134011}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3955591133635248, "sum": 0.3955591133635248, "min": 0.3955591133635248}}, "EndTime": 1575128661.13408, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575128661.134064}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.46801853078334177, "sum": 0.46801853078334177, "min": 0.46801853078334177}}, "EndTime": 1575128661.134139, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575128661.134122}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.31397018827505446, "sum": 0.31397018827505446, "min": 0.31397018827505446}}, "EndTime": 1575128661.134201, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575128661.134184}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.31883016607389975, "sum": 0.31883016607389975, "min": 0.31883016607389975}}, "EndTime": 1575128661.134262, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575128661.134245}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.318773566969675, "sum": 0.318773566969675, "min": 0.318773566969675}}, "EndTime": 1575128661.13433, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575128661.134314}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.31588854244366366, "sum": 0.31588854244366366, "min": 0.31588854244366366}}, "EndTime": 1575128661.134384, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575128661.134367}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3880950547223115, "sum": 0.3880950547223115, "min": 0.3880950547223115}}, "EndTime": 1575128661.134441, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575128661.134425}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.44537836180739665, "sum": 0.44537836180739665, "min": 0.44537836180739665}}, "EndTime": 1575128661.134499, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575128661.134483}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3897523921841952, "sum": 0.3897523921841952, "min": 0.3897523921841952}}, "EndTime": 1575128661.134561, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575128661.134544}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4420922755763758, "sum": 0.4420922755763758, "min": 0.4420922755763758}}, "EndTime": 1575128661.13462, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575128661.134604}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.42034308574427315, "sum": 0.42034308574427315, "min": 0.42034308574427315}}, "EndTime": 1575128661.134677, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575128661.13466}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4217867772854752, "sum": 0.4217867772854752, "min": 0.4217867772854752}}, "EndTime": 1575128661.134735, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575128661.134718}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4204658736032457, "sum": 0.4204658736032457, "min": 0.4204658736032457}}, "EndTime": 1575128661.134799, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575128661.134782}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.42170312615016, "sum": 0.42170312615016, "min": 0.42170312615016}}, "EndTime": 1575128661.134855, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575128661.134838}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4497457707659084, "sum": 0.4497457707659084, "min": 0.4497457707659084}}, "EndTime": 1575128661.134912, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575128661.134895}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4579886334481551, "sum": 0.4579886334481551, "min": 0.4579886334481551}}, "EndTime": 1575128661.134969, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575128661.134952}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.44997256414135495, "sum": 0.44997256414135495, "min": 0.44997256414135495}}, "EndTime": 1575128661.135028, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575128661.135016}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4584809010567977, "sum": 0.4584809010567977, "min": 0.4584809010567977}}, "EndTime": 1575128661.135092, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575128661.135075}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.958040394538611, "sum": 0.958040394538611, "min": 0.958040394538611}}, "EndTime": 1575128661.135149, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575128661.135132}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.9621143352566053, "sum": 0.9621143352566053, "min": 0.9621143352566053}}, "EndTime": 1575128661.135206, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575128661.135189}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.9577421559089392, "sum": 0.9577421559089392, "min": 0.9577421559089392}}, "EndTime": 1575128661.135273, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575128661.135256}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.9618703025932888, "sum": 0.9618703025932888, "min": 0.9618703025932888}}, "EndTime": 1575128661.13534, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575128661.135323}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.034266376361176, "sum": 1.034266376361176, "min": 1.034266376361176}}, "EndTime": 1575128661.135398, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575128661.135382}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.0712933809673366, "sum": 1.0712933809673366, "min": 1.0712933809673366}}, "EndTime": 1575128661.13546, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575128661.135444}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.0322164273669372, "sum": 1.0322164273669372, "min": 1.0322164273669372}}, "EndTime": 1575128661.135521, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575128661.135504}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.0702258301548024, "sum": 1.0702258301548024, "min": 1.0702258301548024}}, "EndTime": 1575128661.135555, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575128661.135547}
#
# [11/30/2019 15:44:21 INFO 139723401512768] #quality_metric: host=algo-1, epoch=2, train binary_classification_weighted_cross_entropy_objective <loss>=0.320017239288
# [11/30/2019 15:44:21 INFO 139723401512768] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=binary_classification_weighted_cross_entropy_objective, value=0.306764194968
# [11/30/2019 15:44:21 INFO 139723401512768] Epoch 2: Loss improved. Updating best model
# [11/30/2019 15:44:21 INFO 139723401512768] #progress_metric: host=algo-1, completed 20 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 612, "sum": 612.0, "min": 612}, "Total Records Seen": {"count": 1, "max": 610092, "sum": 610092.0, "min": 610092}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1575128661.138404, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1575128655.360214}
#
# [11/30/2019 15:44:21 INFO 139723401512768] #throughput_metric: host=algo-1, train throughput=34502.0579747 records/second
# [2019-11-30 15:44:27.764] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 9, "duration": 6624, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3076648822956948, "sum": 0.3076648822956948, "min": 0.3076648822956948}}, "EndTime": 1575128667.76472, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1575128667.764616}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.29871208451620895, "sum": 0.29871208451620895, "min": 0.29871208451620895}}, "EndTime": 1575128667.764792, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1575128667.764775}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3024568206557077, "sum": 0.3024568206557077, "min": 0.3024568206557077}}, "EndTime": 1575128667.76485, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1575128667.764833}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3021946404998626, "sum": 0.3021946404998626, "min": 0.3021946404998626}}, "EndTime": 1575128667.764911, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1575128667.764894}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3703386228647663, "sum": 0.3703386228647663, "min": 0.3703386228647663}}, "EndTime": 1575128667.764963, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1575128667.764949}
#
# ...
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.2813307962465526, "sum": 0.2813307962465526, "min": 0.2813307962465526}}, "EndTime": 1575128736.475353, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575128736.475337}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.2830913394563761, "sum": 0.2830913394563761, "min": 0.2830913394563761}}, "EndTime": 1575128736.475395, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575128736.475385}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.28254582659083993, "sum": 0.28254582659083993, "min": 0.28254582659083993}}, "EndTime": 1575128736.475429, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575128736.475417}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.44688612887128515, "sum": 0.44688612887128515, "min": 0.44688612887128515}}, "EndTime": 1575128736.475495, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575128736.475477}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.28263296167574936, "sum": 0.28263296167574936, "min": 0.28263296167574936}}, "EndTime": 1575128736.475559, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575128736.475542}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4467966167699152, "sum": 0.4467966167699152, "min": 0.4467966167699152}}, "EndTime": 1575128736.47563, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575128736.475612}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.28372858873683604, "sum": 0.28372858873683604, "min": 0.28372858873683604}}, "EndTime": 1575128736.475699, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575128736.475682}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.286785213642983, "sum": 0.286785213642983, "min": 0.286785213642983}}, "EndTime": 1575128736.475763, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575128736.475746}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.2851684781941936, "sum": 0.2851684781941936, "min": 0.2851684781941936}}, "EndTime": 1575128736.475854, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575128736.475835}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.2867185094632096, "sum": 0.2867185094632096, "min": 0.2867185094632096}}, "EndTime": 1575128736.475938, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575128736.475916}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.28899151877781853, "sum": 0.28899151877781853, "min": 0.28899151877781853}}, "EndTime": 1575128736.476003, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575128736.475986}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.41493918747638336, "sum": 0.41493918747638336, "min": 0.41493918747638336}}, "EndTime": 1575128736.476071, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575128736.476053}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.28886625341674194, "sum": 0.28886625341674194, "min": 0.28886625341674194}}, "EndTime": 1575128736.476131, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575128736.476114}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.41491490815033266, "sum": 0.41491490815033266, "min": 0.41491490815033266}}, "EndTime": 1575128736.476198, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575128736.476181}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4134301033211713, "sum": 0.4134301033211713, "min": 0.4134301033211713}}, "EndTime": 1575128736.476265, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575128736.476249}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4211000828575249, "sum": 0.4211000828575249, "min": 0.4211000828575249}}, "EndTime": 1575128736.476332, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575128736.476316}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4134430752088077, "sum": 0.4134430752088077, "min": 0.4134430752088077}}, "EndTime": 1575128736.476387, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575128736.476371}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.42109659641591746, "sum": 0.42109659641591746, "min": 0.42109659641591746}}, "EndTime": 1575128736.476445, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575128736.476428}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.42222675043614066, "sum": 0.42222675043614066, "min": 0.42222675043614066}}, "EndTime": 1575128736.4765, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575128736.476486}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.45496609706016045, "sum": 0.45496609706016045, "min": 0.45496609706016045}}, "EndTime": 1575128736.476533, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575128736.476525}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.42222457203313934, "sum": 0.42222457203313934, "min": 0.42222457203313934}}, "EndTime": 1575128736.476587, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575128736.47657}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4633168626334799, "sum": 0.4633168626334799, "min": 0.4633168626334799}}, "EndTime": 1575128736.476656, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575128736.476639}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.9556941025317015, "sum": 0.9556941025317015, "min": 0.9556941025317015}}, "EndTime": 1575128736.476715, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575128736.476698}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.9596021958547621, "sum": 0.9596021958547621, "min": 0.9596021958547621}}, "EndTime": 1575128736.476772, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575128736.476756}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.9556963950305728, "sum": 0.9556963950305728, "min": 0.9556963950305728}}, "EndTime": 1575128736.476838, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575128736.476821}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.95959608191102, "sum": 0.95959608191102, "min": 0.95959608191102}}, "EndTime": 1575128736.476896, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575128736.476879}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.9620679416368955, "sum": 0.9620679416368955, "min": 0.9620679416368955}}, "EndTime": 1575128736.476956, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575128736.476939}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.0504145776949936, "sum": 1.0504145776949936, "min": 1.0504145776949936}}, "EndTime": 1575128736.477011, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575128736.476996}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.9620633925241442, "sum": 0.9620633925241442, "min": 0.9620633925241442}}, "EndTime": 1575128736.477079, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575128736.477061}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.050424174323154, "sum": 1.050424174323154, "min": 1.050424174323154}}, "EndTime": 1575128736.477137, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575128736.477121}
#
# [11/30/2019 15:45:36 INFO 139723401512768] #quality_metric: host=algo-1, epoch=14, train binary_classification_weighted_cross_entropy_objective <loss>=0.283454293064
# [11/30/2019 15:45:36 INFO 139723401512768] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=binary_classification_weighted_cross_entropy_objective, value=0.281330796247
# [11/30/2019 15:45:36 INFO 139723401512768] Epoch 14: Loss improved. Updating best model
# [11/30/2019 15:45:36 INFO 139723401512768] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 3012, "sum": 3012.0, "min": 3012}, "Total Records Seen": {"count": 1, "max": 3002460, "sum": 3002460.0, "min": 3002460}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 17, "sum": 17.0, "min": 17}}, "EndTime": 1575128736.479569, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1575128730.200312}
#
# [11/30/2019 15:45:36 INFO 139723401512768] #throughput_metric: host=algo-1, train throughput=31749.0445368 records/second
# [11/30/2019 15:45:36 WARNING 139723401512768] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [11/30/2019 15:45:36 WARNING 139723401512768] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2019-11-30 15:45:36.486] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 33, "duration": 5, "num_examples": 1, "num_bytes": 168000}
# [2019-11-30 15:45:37.160] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 36, "duration": 671, "num_examples": 200, "num_bytes": 33493152}
# [2019-11-30 15:45:37.863] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 38, "duration": 631, "num_examples": 200, "num_bytes": 33493152}
# [11/30/2019 15:45:37 INFO 139723401512768] #train_score (algo-1) : ('binary_classification_weighted_cross_entropy_objective', 0.2799641856273543)
# [11/30/2019 15:45:37 INFO 139723401512768] #train_score (algo-1) : ('binary_classification_accuracy', 0.9702855079151702)
# [11/30/2019 15:45:37 INFO 139723401512768] #train_score (algo-1) : ('binary_f_1.000', 0.09474327628361859)
# [11/30/2019 15:45:37 INFO 139723401512768] #train_score (algo-1) : ('precision', 0.04998387616897775)
# [11/30/2019 15:45:37 INFO 139723401512768] #train_score (algo-1) : ('recall', 0.9064327485380117)
# [11/30/2019 15:45:37 INFO 139723401512768] #quality_metric: host=algo-1, train binary_classification_weighted_cross_entropy_objective <loss>=0.279964185627
# [11/30/2019 15:45:37 INFO 139723401512768] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.970285507915
# [11/30/2019 15:45:37 INFO 139723401512768] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.0947432762836
# [11/30/2019 15:45:37 INFO 139723401512768] #quality_metric: host=algo-1, train precision <score>=0.049983876169
# [11/30/2019 15:45:37 INFO 139723401512768] #quality_metric: host=algo-1, train recall <score>=0.906432748538
# [11/30/2019 15:45:37 INFO 139723401512768] Best model found for hyperparameters: {"lr_scheduler_step": 10, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.005, "lr_scheduler_minimum_lr": 0.0001}
# [11/30/2019 15:45:37 INFO 139723401512768] Saved checkpoint to "/tmp/tmpe2IJ00/mx-mod-0000.params"
# [11/30/2019 15:45:37 INFO 139723401512768] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 96387.25590705872, "sum": 96387.25590705872, "min": 96387.25590705872}, "finalize.time": {"count": 1, "max": 1384.3328952789307, "sum": 1384.3328952789307, "min": 1384.3328952789307}, "initialize.time": {"count": 1, "max": 261.11912727355957, "sum": 261.11912727355957, "min": 261.11912727355957}, "check_early_stopping.time": {"count": 15, "max": 1.0390281677246094, "sum": 13.089895248413086, "min": 0.7429122924804688}, "setuptime": {"count": 1, "max": 26.051998138427734, "sum": 26.051998138427734, "min": 26.051998138427734}, "update.time": {"count": 15, "max": 7294.044971466064, "sum": 94609.88593101501, "min": 5641.401052474976}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1575128737.876747, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1575128641.576407}
#
#
# 2019-11-30 15:45:49 Completed - Training job completed
# Training seconds: 148
# Billable seconds: 148
# CPU times: user 786 ms, sys: 46.3 ms, total: 832 ms
# Wall time: 5min 43s

# %% [markdown]
# ### EXERCISE: Deploy and evaluate the balanced estimator
#
# Deploy the balanced predictor and evaluate it. Do the results match with your expectations?

# %%
# %%time 
# deploy and create a predictor
balanced_predictor = linear_balanced.deploy(
    initial_instance_count=1,
    instance_type='ml.t2.medium'
)
# Out:
# ---------------------------------------------------------------------------------------------------------------!CPU times: user 603 ms, sys: 14.1 ms, total: 617 ms
# Wall time: 9min 19s

# %%
print('Metrics for balanced, LinearLearner.\n')

# get metrics for balanced predictor
metrics = evaluate(balanced_predictor, 
                   test_features.astype('float32'), 
                   test_labels, 
                   verbose=True)
# Out:
# Metrics for balanced, LinearLearner.
#
# prediction (col)    0.0   1.0
# actual (row)
# 0                 82821  2472
# 1                     7   143
#
# Recall:     0.953
# Precision:  0.055
# Accuracy:   0.971

# %% [markdown]
# ## Delete the endpoint
#
# When you're done evaluating a model, you should delete the endpoint.

# %%
# delete the predictor endpoint 
delete_endpoint(balanced_predictor)
# Out:
# Already deleted: linear-learner-2019-11-30-15-40-43-805

# %% [markdown]
# A note on metric variability:
#
# The above model is tuned for the best possible precision with recall fixed at about 90%. The recall is fixed at 90% during training, but may vary when we apply our trained model to a test set of data.

# %% [markdown]
# ---
# ## Model Design
#
# Now that you've seen how to tune and balance a LinearLearner. Create, train and deploy your own model. This exercise is meant to be more open-ended, so that you get practice with the steps involved in designing a model and deploying it.
#
# ### EXERCISE: Train and deploy a LinearLearner with appropriate hyperparameters, according to the given scenario
#
# **Scenario:**
# * A bank has asked you to build a model that optimizes for a good user experience; users should only ever have up to about 15% of their valid transactions flagged as fraudulent.
#
# This requires that you make a design decision: Given the above scenario, what metric (and value) should you aim for during training?
#
# You may assume that performance on a training set will be within about 5-10% of the performance on a test set. For example, if you get 80% on a training set, you can assume that you'll get between about 70-90% accuracy on a test set.
#
# Your final model should account for class imbalance and be appropriately tuned.

# %%
# %%time
# instantiate and train a LinearLearner

# include params for tuning for higher precision
# *and* account for class imbalance in training data

# %%
# %%time 
# deploy and evaluate a predictor

# %%
## IMPORTANT
# delete the predictor endpoint after evaluation

# %% [markdown]
# ## Final Cleanup!
#
# * Double check that you have deleted all your endpoints.
# * I'd also suggest manually deleting your S3 bucket, models, and endpoint configurations directly from your AWS console.
#
# You can find thorough cleanup instructions, [in the documentation](https://docs.aws.amazon.com/sagemaker/latest/dg/ex1-cleanup.html).

# %% [markdown]
# ---
# # Conclusion
#
# In this notebook, you saw how to train and deploy a LinearLearner in SageMaker. This model is well-suited for a binary classification task that involves specific design decisions and managing class imbalance in the training set.
#
# Following the steps of a machine learning workflow, you loaded in some credit card transaction data, explored that data and prepared it for model training. Then trained, deployed, and evaluated several models, according to different design considerations!
